# %%
# Turning into a dataframe because easiest way I can find online to pretty format this 
import pandas as pd
import numpy as np
from pickle import load
from nltk import download
from nltk.corpus import stopwords

# %%
with open("exploratory_table.pickle", "rb") as handle:
    table = load(handle)

df = pd.DataFrame.from_dict(table, orient="index")

# %%
with open("confidence_intervals.pickle", "rb") as handle:
    CI = load(handle)

# %%
CI = pd.Series(CI)
df["CI (90%)"] = CI

# %%
split_CI = pd.DataFrame(df["CI (90%)"].to_list(), columns=["min","max"], index=df.index)
df["Significant"] = np.where((0 < split_CI["min"]), True, False)

# %%
df = df.sort_values(by=["PPMI"], ascending=False)

# Filter out stopwords using nltk and words not used by female speakers
stop = set(stopwords.words("english"))
filtered_df = df.loc[(~df.index.isin(stop)) & (df["PPMI"] != None)]

# We can set a cutoff for a good PPMI to explore 
# filtered_df = filtered_df.loc[df["PPMI"] < 0.7]
filtered_df = filtered_df.loc[(df["M count"] > 20) & (df["F count"] > 20)]
# filtered_df = filtered_df.loc[df["Significant"] == True]

filtered_df[0:30]
# Out:
#                M count  F count  total   M ratio   F ratio     F - M  \
# generic             46       74    120  0.383333  0.616667  0.233333
# supervised          41       64    105  0.390476  0.609524  0.219048
# imprisonment        28       39     67  0.417910  0.582090  0.164179
# juror               42       55     97  0.432990  0.567010  0.134021
# tva                 21       27     48  0.437500  0.562500  0.125000
# estate              50       63    113  0.442478  0.557522  0.115044
# compelled           32       39     71  0.450704  0.549296  0.098592
# stock               23       28     51  0.450980  0.549020  0.098039
# acquittal           43       52     95  0.452632  0.547368  0.094737
# bias                26       30     56  0.464286  0.535714  0.071429
# significance        33       38     71  0.464789  0.535211  0.070423
# defraud             24       26     50  0.480000  0.520000  0.040000
# verdict             65       67    132  0.492424  0.507576  0.015152
# willfulness         28       28     56  0.500000  0.500000  0.000000
# culpability         21       21     42  0.500000  0.500000  0.000000
# cake                27       27     54  0.500000  0.500000  0.000000
# inconsistency       33       32     65  0.507692  0.492308 -0.015385
# priority            48       46     94  0.510638  0.489362 -0.021277
# contempt            40       38     78  0.512821  0.487179 -0.025641
# employment          55       52    107  0.514019  0.485981 -0.028037
# conviction         166      156    322  0.515528  0.484472 -0.031056
# dispositive         27       24     51  0.529412  0.470588 -0.058824
# railroad            46       40     86  0.534884  0.465116 -0.069767
# burr                28       24     52  0.538462  0.461538 -0.076923
# abortion            25       21     46  0.543478  0.456522 -0.086957
# internet            37       30     67  0.552239  0.447761 -0.104478
# release             84       68    152  0.552632  0.447368 -0.105263
# career              36       29     65  0.553846  0.446154 -0.107692
# detention           96       77    173  0.554913  0.445087 -0.109827
# driving             42       32     74  0.567568  0.432432 -0.135135
#
#                    PPMI                                  CI (90%)  Significant
# generic        2.064815  [1.7265679514741603, 2.3079452986104756]         True
# supervised     2.048006   [1.6868330027955702, 2.297745966728624]         True
# imprisonment   1.981565  [1.5885678091260615, 2.2851846318852798]         True
# juror          1.943699  [1.5684539164512645, 2.2282724171688515]         True
# tva            1.932177    [1.336662967681396, 2.318306779551794]         True
# estate         1.919353  [1.4783177880650133, 2.2067107997800344]         True
# compelled      1.897907  [1.5605392505550106, 2.1621664241637095]         True
# stock          1.897181     [1.342010106962817, 2.25053216722741]         True
# acquittal      1.892836  [1.4273998247628346, 2.2412072766705626]         True
# bias           1.861787    [1.336719655147427, 2.216357167351706]         True
# significance   1.860432   [1.3143875433695826, 2.167851761346754]         True
# defraud        1.818835  [1.2359431861533006, 2.2222473319638474]         True
# verdict        1.783947  [1.2585685996905671, 2.1087059612536483]         True
# willfulness    1.762252   [1.0918921480658657, 2.201920691955478]         True
# culpability    1.762252  [1.2113431284486549, 2.1540328548823777]         True
# cake           1.762252   [1.1593245273622192, 2.162281363326177]         True
# inconsistency  1.739884  [1.1660462437776586, 2.1100385437384808]         True
# priority       1.731225  [1.2644309170422205, 2.0575902836116686]         True
# contempt       1.724777    [1.111452087105155, 2.101137747940889]         True
# employment     1.721225   [1.3297379500663538, 2.013229775534002]         True
# conviction     1.716737  [1.4777325875794227, 1.9194279925244067]         True
# dispositive    1.674789   [1.1854922062765394, 2.021521840554276]         True
# railroad       1.657915   [1.1691314770494337, 2.055314196554122]         True
# burr           1.646775   [0.9520210708199067, 2.089305848383223]         True
# abortion       1.631007   [0.6259503712792952, 2.149030624447957]         True
# internet       1.603053  [1.0198426663141889, 1.9960077187464027]         True
# release        1.601787  [1.2153427328534494, 1.8921357313383453]         True
# career         1.597865  [0.8929612832428311, 2.1706276445721238]         True
# detention      1.594410  [1.2105970661920094, 1.8955878107512407]         True
# driving        1.552798  [1.1033101412688369, 1.9079499635816133]         True

# %%
df.loc["woman"]
# Out:
# M count                                             113
# F count                                              67
# total                                               180
# M ratio                                        0.627778
# F ratio                                        0.372222
# F - M                                         -0.255556
# PPMI                                           1.336488
# CI (90%)       [0.9244332882936098, 1.6670263911063088]
# Significant                                        True
# Name: woman, dtype: object

# %%
filtered_df.to_csv("final_results_table.csv")
