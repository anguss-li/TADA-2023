# %%
# Turning into a dataframe because easiest way I can find online to pretty format this 
import pandas as pd
from pickle import load

# %%
with open('exploratory_table.pickle', 'rb') as handle:
    table = load(handle)

df = df = pd.DataFrame.from_dict(table, orient='index')
df = df.sort_values(by=['total'], ascending=False)

# %%
df
# Out:
#                               counts  \
# the         {'M': 91713, 'F': 15437}
# ,           {'M': 83237, 'F': 14395}
# .           {'M': 61660, 'F': 10856}
# that         {'M': 51762, 'F': 9340}
# --           {'M': 40887, 'F': 6186}
# ...                              ...
# fifths                      {'M': 1}
# giveaway                    {'M': 1}
# inspect                     {'M': 1}
# secondhand                  {'M': 1}
# repository                  {'M': 1}
#
#                                                         ratio   total
# the         {'M': 0.8559309379374709, 'F': 0.1440690620625...  107150
# ,           {'M': 0.8525585873484104, 'F': 0.1474414126515...   97632
# .           {'M': 0.8502951072866678, 'F': 0.1497048927133...   72516
# that        {'M': 0.8471408464534712, 'F': 0.1528591535465...   61102
# --          {'M': 0.8685870881396979, 'F': 0.1314129118603...   47073
# ...                                                       ...     ...
# fifths                    {'M': 1.0, 'F': 0.0, 'F - M': -1.0}       1
# giveaway                  {'M': 1.0, 'F': 0.0, 'F - M': -1.0}       1
# inspect                   {'M': 1.0, 'F': 0.0, 'F - M': -1.0}       1
# secondhand                {'M': 1.0, 'F': 0.0, 'F - M': -1.0}       1
# repository                {'M': 1.0, 'F': 0.0, 'F - M': -1.0}       1
#
# [19750 rows x 3 columns]
