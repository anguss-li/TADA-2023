# %%
# Turning into a dataframe because easiest way I can find online to pretty format this 
import pandas as pd
from pickle import load
from nltk import download
from nltk.corpus import stopwords

# %%
with open('exploratory_table.pickle', 'rb') as handle:
    table = load(handle)

df = df = pd.DataFrame.from_dict(table, orient='index')

# %%
df = df.sort_values(by=['PPMI'], ascending=False)

# Filter out stopwords using nltk and words not used by female speakers
stop = set(stopwords.words("english"))
filtered_df = df.loc[(~df.index.isin(stop)) & (df["PPMI"] != None)]

# We can set a cutoff for a good PPMI to explore 
filtered_df = filtered_df.loc[df["PPMI"] > 0.1]
filtered_df = filtered_df.loc[(df["M count"] > 20) & (df["F count"] > 20)]

filtered_df[0:30]
# Out:
#                M count  F count  total   M ratio   F ratio     F - M      PPMI
# generic             46       74    120  0.383333  0.616667  0.233333  2.064815
# supervised          41       64    105  0.390476  0.609524  0.219048  2.048006
# imprisonment        28       39     67  0.417910  0.582090  0.164179  1.981565
# juror               42       55     97  0.432990  0.567010  0.134021  1.943699
# tva                 21       27     48  0.437500  0.562500  0.125000  1.932177
# estate              50       63    113  0.442478  0.557522  0.115044  1.919353
# compelled           32       39     71  0.450704  0.549296  0.098592  1.897907
# stock               23       28     51  0.450980  0.549020  0.098039  1.897181
# acquittal           43       52     95  0.452632  0.547368  0.094737  1.892836
# bias                26       30     56  0.464286  0.535714  0.071429  1.861787
# significance        33       38     71  0.464789  0.535211  0.070423  1.860432
# defraud             24       26     50  0.480000  0.520000  0.040000  1.818835
# verdict             65       67    132  0.492424  0.507576  0.015152  1.783947
# culpability         21       21     42  0.500000  0.500000  0.000000  1.762252
# willfulness         28       28     56  0.500000  0.500000  0.000000  1.762252
# cake                27       27     54  0.500000  0.500000  0.000000  1.762252
# inconsistency       33       32     65  0.507692  0.492308 -0.015385  1.739884
# priority            48       46     94  0.510638  0.489362 -0.021277  1.731225
# contempt            40       38     78  0.512821  0.487179 -0.025641  1.724777
# employment          55       52    107  0.514019  0.485981 -0.028037  1.721225
# conviction         166      156    322  0.515528  0.484472 -0.031056  1.716737
# dispositive         27       24     51  0.529412  0.470588 -0.058824  1.674789
# railroad            46       40     86  0.534884  0.465116 -0.069767  1.657915
# burr                28       24     52  0.538462  0.461538 -0.076923  1.646775
# abortion            25       21     46  0.543478  0.456522 -0.086957  1.631007
# internet            37       30     67  0.552239  0.447761 -0.104478  1.603053
# release             84       68    152  0.552632  0.447368 -0.105263  1.601787
# career              36       29     65  0.553846  0.446154 -0.107692  1.597865
# detention           96       77    173  0.554913  0.445087 -0.109827  1.594410
# driving             42       32     74  0.567568  0.432432 -0.135135  1.552798

# %%
# Potential words I've found quickly looking through
filtered_df.loc["man"]
# Out:
# M count    56.000000
# F count    38.000000
# total      94.000000
# M ratio     0.595745
# F ratio     0.404255
# F - M      -0.191489
# PPMI        1.455590
# Name: man, dtype: float64

# %%
df.shape
# Out:
# (18984, 7)
