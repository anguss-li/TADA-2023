# %%
from typing import Dict, Iterable, List, Tuple
from convokit import Corpus, Speaker, Utterance, download
from collections import defaultdict, Counter

# %%
corpus = Corpus(filename="../supreme_processed")

# Filter out speakers without gender signal
corpus = corpus.filter_utterances_by(
    lambda utt: utt.get_speaker().retrieve_meta("gender_signal") != None
)

# %%
# Our goal is to build a table with each word token in the vocabulary for the Supreme Court corpus, 
# listing the number of male and female speakers as well as some percentages.
counts = defaultdict(Counter)
# keys: tokens in the vocabulary
        # values: Counter dictionaries 
            #keys: gender signals
            #values: how many speakers of given gender have said the token

"""Flattens the "tokens" dictionary of an Utterance into a list."""
def get_tokens(utt: Utterance) -> List[str]:
    return [tok["tok"]
            for sent in utt.retrieve_meta("tokens")
            for tok in sent["toks"]]

for utt in corpus.iter_utterances():
    tokens = get_tokens(utt)
    gender = utt.get_speaker().retrieve_meta("gender_signal")
    for token in tokens:
        counts[token][gender] += 1

# Add percentages in a second run because this is a bit neater.
table = defaultdict(defaultdict)
# keys: tokens in the vocabulary
        # values: defaultdicts 
            #keys: either "counts" or "ratio"
            #values: data for male and female speakers

for token in counts: 
    table[token]["counts"] = counts[token]
    table[token]["ratio"] = defaultdict()
    
    total_speakers = table[token]["counts"]["M"] + table[token]["counts"]["F"]
    table[token]["ratio"]["M"] = table[token]["counts"]["M"] / total_speakers
    table[token]["ratio"]["F"] = table[token]["counts"]["F"] / total_speakers
    table[token]["ratio"]["F - M"] = table[token]["ratio"]["F"] - table[token]["ratio"]["M"]

table
# Out:
# defaultdict(collections.defaultdict,
#             {'mr': defaultdict(None,
#                          {'counts': Counter({'M': 353, 'F': 52}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8716049382716049,
#                                        'F': 0.12839506172839507,
#                                        'F - M': -0.7432098765432098})}),
#              '.': defaultdict(None,
#                          {'counts': Counter({'M': 14717, 'F': 2273}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8662154208357857,
#                                        'F': 0.13378457916421424,
#                                        'F - M': -0.7324308416715715})}),
#              'chief': defaultdict(None,
#                          {'counts': Counter({'M': 245, 'F': 40}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8596491228070176,
#                                        'F': 0.14035087719298245,
#                                        'F - M': -0.7192982456140351})}),
#              'justice': defaultdict(None,
#                          {'counts': Counter({'M': 962, 'F': 149}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8658865886588659,
#                                        'F': 0.1341134113411341,
#                                        'F - M': -0.7317731773177318})}),
#              ',': defaultdict(None,
#                          {'counts': Counter({'M': 19757, 'F': 2859}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8735850725150336,
#                                        'F': 0.12641492748496638,
#                                        'F - M': -0.7471701450300672})}),
#              'and': defaultdict(None,
#                          {'counts': Counter({'M': 8012, 'F': 1228}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8670995670995671,
#                                        'F': 0.1329004329004329,
#                                        'F - M': -0.7341991341991343})}),
#              'may': defaultdict(None,
#                          {'counts': Counter({'M': 363, 'F': 58}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8622327790973872,
#                                        'F': 0.1377672209026128,
#                                        'F - M': -0.7244655581947743})}),
#              'it': defaultdict(None,
#                          {'counts': Counter({'M': 5769, 'F': 906}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8642696629213483,
#                                        'F': 0.13573033707865167,
#                                        'F - M': -0.7285393258426967})}),
#              'please': defaultdict(None,
#                          {'counts': Counter({'M': 133, 'F': 21}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8636363636363636,
#                                        'F': 0.13636363636363635,
#                                        'F - M': -0.7272727272727273})}),
#              'the': defaultdict(None,
#                          {'counts': Counter({'M': 22049, 'F': 2563}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8958638062733626,
#                                        'F': 0.10413619372663742,
#                                        'F - M': -0.7917276125467252})}),
#              'court': defaultdict(None,
#                          {'counts': Counter({'M': 2401, 'F': 349}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8730909090909091,
#                                        'F': 0.12690909090909092,
#                                        'F - M': -0.7461818181818183})}),
#              ':': defaultdict(None,
#                          {'counts': Counter({'M': 268, 'F': 42}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.864516129032258,
#                                        'F': 0.13548387096774195,
#                                        'F - M': -0.7290322580645161})}),
#              'when': defaultdict(None,
#                          {'counts': Counter({'M': 673, 'F': 96}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8751625487646294,
#                                        'F': 0.12483745123537061,
#                                        'F - M': -0.7503250975292588})}),
#              'states': defaultdict(None,
#                          {'counts': Counter({'M': 371, 'F': 32}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9205955334987593,
#                                        'F': 0.0794044665012407,
#                                        'F - M': -0.8411910669975187})}),
#              'infringe': defaultdict(None,
#                          {'counts': Counter({'M': 9, 'F': 1}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9, 'F': 0.1, 'F - M': -0.8})}),
#              'exclusive': defaultdict(None,
#                          {'counts': Counter({'M': 19}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'federal': defaultdict(None,
#                          {'counts': Counter({'M': 418, 'F': 29}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9351230425055929,
#                                        'F': 0.06487695749440715,
#                                        'F - M': -0.8702460850111857})}),
#              'rights': defaultdict(None,
#                          {'counts': Counter({'M': 147, 'F': 9}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9423076923076923,
#                                        'F': 0.057692307692307696,
#                                        'F - M': -0.8846153846153846})}),
#              'that': defaultdict(None,
#                          {'counts': Counter({'M': 12310, 'F': 1745}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8758448950551405,
#                                        'F': 0.12415510494485948,
#                                        'F - M': -0.751689790110281})}),
#              'congress': defaultdict(None,
#                          {'counts': Counter({'M': 1010, 'F': 31}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9702209414024976,
#                                        'F': 0.029779058597502402,
#                                        'F - M': -0.9404418828049952})}),
#              'is': defaultdict(None,
#                          {'counts': Counter({'M': 5953, 'F': 891}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.869812974868498,
#                                        'F': 0.13018702513150204,
#                                        'F - M': -0.7396259497369959})}),
#              'charged': defaultdict(None,
#                          {'counts': Counter({'M': 17, 'F': 1}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9444444444444444,
#                                        'F': 0.05555555555555555,
#                                        'F - M': -0.8888888888888888})}),
#              'with': defaultdict(None,
#                          {'counts': Counter({'M': 1518, 'F': 177}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8955752212389381,
#                                        'F': 0.10442477876106195,
#                                        'F - M': -0.7911504424778761})}),
#              'securing': defaultdict(None,
#                          {'counts': Counter({'M': 3, 'F': 1}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.75, 'F': 0.25, 'F - M': -0.5})}),
#              'can': defaultdict(None,
#                          {'counts': Counter({'M': 777, 'F': 128}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8585635359116022,
#                                        'F': 0.1414364640883978,
#                                        'F - M': -0.7171270718232043})}),
#              'make': defaultdict(None,
#                          {'counts': Counter({'M': 415, 'F': 49}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8943965517241379,
#                                        'F': 0.10560344827586207,
#                                        'F - M': -0.7887931034482758})}),
#              'pay': defaultdict(None,
#                          {'counts': Counter({'M': 127, 'F': 6}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9548872180451128,
#                                        'F': 0.045112781954887216,
#                                        'F - M': -0.9097744360902256})}),
#              'for': defaultdict(None,
#                          {'counts': Counter({'M': 2306, 'F': 282}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8910355486862442,
#                                        'F': 0.10896445131375579,
#                                        'F - M': -0.7820710973724885})}),
#              'doing': defaultdict(None,
#                          {'counts': Counter({'M': 151, 'F': 10}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.937888198757764,
#                                        'F': 0.062111801242236024,
#                                        'F - M': -0.8757763975155279})}),
#              'so': defaultdict(None,
#                          {'counts': Counter({'M': 1837, 'F': 401}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8208221626452189,
#                                        'F': 0.17917783735478104,
#                                        'F - M': -0.6416443252904378})}),
#              "'s": defaultdict(None,
#                          {'counts': Counter({'M': 5225, 'F': 802}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8669321387091422,
#                                        'F': 0.13306786129085782,
#                                        'F - M': -0.7338642774182844})}),
#              'our': defaultdict(None,
#                          {'counts': Counter({'M': 586, 'F': 78}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8825301204819277,
#                                        'F': 0.11746987951807229,
#                                        'F - M': -0.7650602409638554})}),
#              'respectful': defaultdict(None,
#                          {'counts': Counter({'M': 5}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'submission': defaultdict(None,
#                          {'counts': Counter({'M': 25}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'today': defaultdict(None,
#                          {'counts': Counter({'M': 80, 'F': 19}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8080808080808081,
#                                        'F': 0.1919191919191919,
#                                        'F - M': -0.6161616161616161})}),
#              'one': defaultdict(None,
#                          {'counts': Counter({'M': 836, 'F': 130}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.865424430641822,
#                                        'F': 0.13457556935817805,
#                                        'F - M': -0.7308488612836439})}),
#              'follows': defaultdict(None,
#                          {'counts': Counter({'M': 14, 'F': 2}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.875,
#                                        'F': 0.125,
#                                        'F - M': -0.75})}),
#              'from': defaultdict(None,
#                          {'counts': Counter({'M': 891, 'F': 101}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8981854838709677,
#                                        'F': 0.10181451612903226,
#                                        'F - M': -0.7963709677419355})}),
#              'constitution': defaultdict(None,
#                          {'counts': Counter({'M': 107, 'F': 2}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.981651376146789,
#                                        'F': 0.01834862385321101,
#                                        'F - M': -0.963302752293578})}),
#              'text': defaultdict(None,
#                          {'counts': Counter({'M': 183, 'F': 5}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.973404255319149,
#                                        'F': 0.026595744680851064,
#                                        'F - M': -0.946808510638298})}),
#              'affords': defaultdict(None,
#                          {'counts': Counter({'M': 3}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'ample': defaultdict(None,
#                          {'counts': Counter({'M': 6}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'basis': defaultdict(None,
#                          {'counts': Counter({'M': 136, 'F': 14}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9066666666666666,
#                                        'F': 0.09333333333333334,
#                                        'F - M': -0.8133333333333332})}),
#              'this': defaultdict(None,
#                          {'counts': Counter({'M': 3116, 'F': 454}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8728291316526611,
#                                        'F': 0.12717086834733893,
#                                        'F - M': -0.7456582633053221})}),
#              'to': defaultdict(None,
#                          {'counts': Counter({'M': 9580, 'F': 1249}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8846615569304644,
#                                        'F': 0.1153384430695355,
#                                        'F - M': -0.7693231138609289})}),
#              'uphold': defaultdict(None,
#                          {'counts': Counter({'M': 9}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'work': defaultdict(None,
#                          {'counts': Counter({'M': 131, 'F': 8}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9424460431654677,
#                                        'F': 0.05755395683453238,
#                                        'F - M': -0.8848920863309353})}),
#              'did': defaultdict(None,
#                          {'counts': Counter({'M': 671, 'F': 87}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8852242744063324,
#                                        'F': 0.11477572559366754,
#                                        'F - M': -0.7704485488126649})}),
#              'in': defaultdict(None,
#                          {'counts': Counter({'M': 6194, 'F': 800}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.885616242493566,
#                                        'F': 0.11438375750643409,
#                                        'F - M': -0.7712324849871319})}),
#              'enacting': defaultdict(None,
#                          {'counts': Counter({'M': 11}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'crca': defaultdict(None,
#                          {'counts': Counter({'M': 13}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'article': defaultdict(None,
#                          {'counts': Counter({'M': 150}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'i': defaultdict(None,
#                          {'counts': Counter({'M': 5570, 'F': 700}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8883572567783095,
#                                        'F': 0.11164274322169059,
#                                        'F - M': -0.7767145135566189})}),
#              'section': defaultdict(None,
#                          {'counts': Counter({'M': 295, 'F': 43}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8727810650887574,
#                                        'F': 0.12721893491124261,
#                                        'F - M': -0.7455621301775148})}),
#              '<': defaultdict(None,
#                          {'counts': Counter({'M': 1864, 'F': 258}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8784165881244109,
#                                        'F': 0.12158341187558906,
#                                        'F - M': -0.7568331762488218})}),
#              'number': defaultdict(None,
#                          {'counts': Counter({'M': 1504, 'F': 220}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8723897911832946,
#                                        'F': 0.12761020881670534,
#                                        'F - M': -0.7447795823665893})}),
#              '>': defaultdict(None,
#                          {'counts': Counter({'M': 1586, 'F': 229}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8738292011019284,
#                                        'F': 0.12617079889807162,
#                                        'F - M': -0.7476584022038568})}),
#              'clause': defaultdict(None,
#                          {'counts': Counter({'M': 181, 'F': 11}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9427083333333334,
#                                        'F': 0.057291666666666664,
#                                        'F - M': -0.8854166666666667})}),
#              'what': defaultdict(None,
#                          {'counts': Counter({'M': 1576, 'F': 221}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8770172509738453,
#                                        'F': 0.1229827490261547,
#                                        'F - M': -0.7540345019476906})}),
#              'we': defaultdict(None,
#                          {'counts': Counter({'M': 2476, 'F': 349}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8764601769911504,
#                                        'F': 0.12353982300884955,
#                                        'F - M': -0.7529203539823008})}),
#              "'re": defaultdict(None,
#                          {'counts': Counter({'M': 969, 'F': 137}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8761301989150091,
#                                        'F': 0.12386980108499096,
#                                        'F - M': -0.7522603978300182})}),
#              'calling': defaultdict(None,
#                          {'counts': Counter({'M': 11, 'F': 2}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8461538461538461,
#                                        'F': 0.15384615384615385,
#                                        'F - M': -0.6923076923076923})}),
#              'intellectual': defaultdict(None,
#                          {'counts': Counter({'M': 6}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'property': defaultdict(None,
#                          {'counts': Counter({'M': 172, 'F': 5}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9717514124293786,
#                                        'F': 0.02824858757062147,
#                                        'F - M': -0.9435028248587571})}),
#              'unique': defaultdict(None,
#                          {'counts': Counter({'M': 20, 'F': 5}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8,
#                                        'F': 0.2,
#                                        'F - M': -0.6000000000000001})}),
#              'within': defaultdict(None,
#                          {'counts': Counter({'M': 157, 'F': 6}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9631901840490797,
#                                        'F': 0.03680981595092025,
#                                        'F - M': -0.9263803680981595})}),
#              'laying': defaultdict(None,
#                          {'counts': Counter({'M': 3}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'down': defaultdict(None,
#                          {'counts': Counter({'M': 94, 'F': 11}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8952380952380953,
#                                        'F': 0.10476190476190476,
#                                        'F - M': -0.7904761904761906})}),
#              'an': defaultdict(None,
#                          {'counts': Counter({'M': 1356, 'F': 180}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8828125,
#                                        'F': 0.1171875,
#                                        'F - M': -0.765625})}),
#              'express': defaultdict(None,
#                          {'counts': Counter({'M': 32, 'F': 2}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9411764705882353,
#                                        'F': 0.058823529411764705,
#                                        'F - M': -0.8823529411764706})}),
#              'constitutional': defaultdict(None,
#                          {'counts': Counter({'M': 170, 'F': 14}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9239130434782609,
#                                        'F': 0.07608695652173914,
#                                        'F - M': -0.8478260869565217})}),
#              'mandate': defaultdict(None,
#                          {'counts': Counter({'M': 28, 'F': 1}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9655172413793104,
#                                        'F': 0.034482758620689655,
#                                        'F - M': -0.9310344827586208})}),
#              'protect': defaultdict(None,
#                          {'counts': Counter({'M': 45, 'F': 9}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8333333333333334,
#                                        'F': 0.16666666666666666,
#                                        'F - M': -0.6666666666666667})}),
#              'specified': defaultdict(None,
#                          {'counts': Counter({'M': 16}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'private': defaultdict(None,
#                          {'counts': Counter({'M': 109, 'F': 2}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9819819819819819,
#                                        'F': 0.018018018018018018,
#                                        'F - M': -0.9639639639639639})}),
#              'against': defaultdict(None,
#                          {'counts': Counter({'M': 185, 'F': 36}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8371040723981901,
#                                        'F': 0.16289592760180996,
#                                        'F - M': -0.6742081447963801})}),
#              'any': defaultdict(None,
#                          {'counts': Counter({'M': 630, 'F': 80}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8873239436619719,
#                                        'F': 0.11267605633802817,
#                                        'F - M': -0.7746478873239437})}),
#              'all': defaultdict(None,
#                          {'counts': Counter({'M': 974, 'F': 117}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8927589367552704,
#                                        'F': 0.10724106324472961,
#                                        'F - M': -0.7855178735105408})}),
#              'intrusion': defaultdict(None,
#                          {'counts': Counter({'M': 6}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'consider': defaultdict(None,
#                          {'counts': Counter({'M': 59, 'F': 21}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.7375,
#                                        'F': 0.2625,
#                                        'F - M': -0.47500000000000003})}),
#              'just': defaultdict(None,
#                          {'counts': Counter({'M': 840, 'F': 195}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8115942028985508,
#                                        'F': 0.18840579710144928,
#                                        'F - M': -0.6231884057971016})}),
#              'how': defaultdict(None,
#                          {'counts': Counter({'M': 328, 'F': 55}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.856396866840731,
#                                        'F': 0.14360313315926893,
#                                        'F - M': -0.712793733681462})}),
#              'pointed': defaultdict(None,
#                          {'counts': Counter({'M': 62, 'F': 9}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8732394366197183,
#                                        'F': 0.1267605633802817,
#                                        'F - M': -0.7464788732394365})}),
#              'clear': defaultdict(None,
#                          {'counts': Counter({'M': 338, 'F': 59}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8513853904282116,
#                                        'F': 0.1486146095717884,
#                                        'F - M': -0.7027707808564232})}),
#              'not': defaultdict(None,
#                          {'counts': Counter({'M': 2873, 'F': 428}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8703423205089367,
#                                        'F': 0.12965767949106333,
#                                        'F - M': -0.7406846410178733})}),
#              'only': defaultdict(None,
#                          {'counts': Counter({'M': 435, 'F': 70}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8613861386138614,
#                                        'F': 0.13861386138613863,
#                                        'F - M': -0.7227722772277227})}),
#              'be': defaultdict(None,
#                          {'counts': Counter({'M': 2385, 'F': 285}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8932584269662921,
#                                        'F': 0.10674157303370786,
#                                        'F - M': -0.7865168539325842})}),
#              'granting': defaultdict(None,
#                          {'counts': Counter({'M': 15, 'F': 1}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9375,
#                                        'F': 0.0625,
#                                        'F - M': -0.875})}),
#              'copyrights': defaultdict(None,
#                          {'counts': Counter({'M': 19}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'but': defaultdict(None,
#                          {'counts': Counter({'M': 1968, 'F': 309}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8642951251646904,
#                                        'F': 0.13570487483530963,
#                                        'F - M': -0.7285902503293809})}),
#              'them': defaultdict(None,
#                          {'counts': Counter({'M': 345, 'F': 48}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8778625954198473,
#                                        'F': 0.12213740458015267,
#                                        'F - M': -0.7557251908396947})}),
#              'resulting': defaultdict(None,
#                          {'counts': Counter({'M': 4, 'F': 1}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8,
#                                        'F': 0.2,
#                                        'F - M': -0.6000000000000001})}),
#              'by': defaultdict(None,
#                          {'counts': Counter({'M': 953, 'F': 99}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.905893536121673,
#                                        'F': 0.094106463878327,
#                                        'F - M': -0.811787072243346})}),
#              'definition': defaultdict(None,
#                          {'counts': Counter({'M': 59, 'F': 5}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.921875,
#                                        'F': 0.078125,
#                                        'F - M': -0.84375})}),
#              'are': defaultdict(None,
#                          {'counts': Counter({'M': 1755, 'F': 269}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8670948616600791,
#                                        'F': 0.13290513833992096,
#                                        'F - M': -0.7341897233201582})}),
#              'meant': defaultdict(None,
#                          {'counts': Counter({'M': 43, 'F': 3}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9347826086956522,
#                                        'F': 0.06521739130434782,
#                                        'F - M': -0.8695652173913044})}),
#              'whom': defaultdict(None,
#                          {'counts': Counter({'M': 13, 'F': 3}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8125,
#                                        'F': 0.1875,
#                                        'F - M': -0.625})}),
#              'your': defaultdict(None,
#                          {'counts': Counter({'M': 952, 'F': 120}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8880597014925373,
#                                        'F': 0.11194029850746269,
#                                        'F - M': -0.7761194029850746})}),
#              'honors': defaultdict(None,
#                          {'counts': Counter({'M': 18, 'F': 1}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9473684210526315,
#                                        'F': 0.05263157894736842,
#                                        'F - M': -0.894736842105263})}),
#              '?': defaultdict(None,
#                          {'counts': Counter({'M': 327, 'F': 53}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8605263157894737,
#                                        'F': 0.1394736842105263,
#                                        'F - M': -0.7210526315789474})}),
#              'comers': defaultdict(None,
#                          {'counts': Counter({'M': 1}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'world': defaultdict(None,
#                          {'counts': Counter({'M': 33, 'F': 12}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.7333333333333333,
#                                        'F': 0.26666666666666666,
#                                        'F - M': -0.4666666666666666})}),
#              'including': defaultdict(None,
#                          {'counts': Counter({'M': 89, 'F': 17}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.839622641509434,
#                                        'F': 0.16037735849056603,
#                                        'F - M': -0.679245283018868})}),
#              'government': defaultdict(None,
#                          {'counts': Counter({'M': 605, 'F': 32}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9497645211930926,
#                                        'F': 0.05023547880690738,
#                                        'F - M': -0.8995290423861853})}),
#              'exercise': defaultdict(None,
#                          {'counts': Counter({'M': 87, 'F': 2}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9775280898876404,
#                                        'F': 0.02247191011235955,
#                                        'F - M': -0.9550561797752808})}),
#              'of': defaultdict(None,
#                          {'counts': Counter({'M': 8056, 'F': 1077}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8820759881747509,
#                                        'F': 0.1179240118252491,
#                                        'F - M': -0.7641519763495017})}),
#              'congressional': defaultdict(None,
#                          {'counts': Counter({'M': 39, 'F': 4}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9069767441860465,
#                                        'F': 0.09302325581395349,
#                                        'F - M': -0.8139534883720929})}),
#              'power': defaultdict(None,
#                          {'counts': Counter({'M': 199, 'F': 5}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9754901960784313,
#                                        'F': 0.024509803921568627,
#                                        'F - M': -0.9509803921568627})}),
#              'serves': defaultdict(None,
#                          {'counts': Counter({'M': 5, 'F': 2}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.7142857142857143,
#                                        'F': 0.2857142857142857,
#                                        'F - M': -0.4285714285714286})}),
#              'purpose': defaultdict(None,
#                          {'counts': Counter({'M': 83, 'F': 1}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9880952380952381,
#                                        'F': 0.011904761904761904,
#                                        'F - M': -0.9761904761904763})}),
#              'promote': defaultdict(None,
#                          {'counts': Counter({'M': 6}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'progress': defaultdict(None,
#                          {'counts': Counter({'M': 6}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'affording': defaultdict(None,
#                          {'counts': Counter({'M': 3}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'monetary': defaultdict(None,
#                          {'counts': Counter({'M': 9, 'F': 6}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.6,
#                                        'F': 0.4,
#                                        'F - M': -0.19999999999999996})}),
#              'recompense': defaultdict(None,
#                          {'counts': Counter({'M': 1}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'copyright': defaultdict(None,
#                          {'counts': Counter({'M': 108, 'F': 1}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9908256880733946,
#                                        'F': 0.009174311926605505,
#                                        'F - M': -0.9816513761467891})}),
#              'holders': defaultdict(None,
#                          {'counts': Counter({'M': 17}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'framers': defaultdict(None,
#                          {'counts': Counter({'M': 26}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'thus': defaultdict(None,
#                          {'counts': Counter({'M': 13, 'F': 5}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.7222222222222222,
#                                        'F': 0.2777777777777778,
#                                        'F - M': -0.4444444444444444})}),
#              'made': defaultdict(None,
#                          {'counts': Counter({'M': 275, 'F': 28}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9075907590759076,
#                                        'F': 0.0924092409240924,
#                                        'F - M': -0.8151815181518152})}),
#              'very': defaultdict(None,
#                          {'counts': Counter({'M': 466, 'F': 70}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8694029850746269,
#                                        'F': 0.13059701492537312,
#                                        'F - M': -0.7388059701492538})}),
#              'those': defaultdict(None,
#                          {'counts': Counter({'M': 749, 'F': 96}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8863905325443787,
#                                        'F': 0.1136094674556213,
#                                        'F - M': -0.7727810650887574})}),
#              'wanting': defaultdict(None,
#                          {'counts': Counter({'M': 2}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'use': defaultdict(None,
#                          {'counts': Counter({'M': 214, 'F': 36}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.856,
#                                        'F': 0.144,
#                                        'F - M': -0.712})}),
#              'author': defaultdict(None,
#                          {'counts': Counter({'M': 4}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'paying': defaultdict(None,
#                          {'counts': Counter({'M': 14}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'money': defaultdict(None,
#                          {'counts': Counter({'M': 132, 'F': 12}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9166666666666666,
#                                        'F': 0.08333333333333333,
#                                        'F - M': -0.8333333333333333})}),
#              'signals': defaultdict(None,
#                          {'counts': Counter({'M': 7}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'a': defaultdict(None,
#                          {'counts': Counter({'M': 6963, 'F': 1058}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8680962473507045,
#                                        'F': 0.1319037526492956,
#                                        'F - M': -0.7361924947014089})}),
#              'plan': defaultdict(None,
#                          {'counts': Counter({'M': 150, 'F': 10}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9375,
#                                        'F': 0.0625,
#                                        'F - M': -0.875})}),
#              'convention': defaultdict(None,
#                          {'counts': Counter({'M': 125}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'waiver': defaultdict(None,
#                          {'counts': Counter({'M': 12, 'F': 3}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8,
#                                        'F': 0.2,
#                                        'F - M': -0.6000000000000001})}),
#              'like': defaultdict(None,
#                          {'counts': Counter({'M': 568, 'F': 102}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8477611940298507,
#                                        'F': 0.15223880597014924,
#                                        'F - M': -0.6955223880597015})}),
#              'no': defaultdict(None,
#                          {'counts': Counter({'M': 1141, 'F': 196}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8534031413612565,
#                                        'F': 0.14659685863874344,
#                                        'F - M': -0.706806282722513})}),
#              'other': defaultdict(None,
#                          {'counts': Counter({'M': 662, 'F': 124}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8422391857506362,
#                                        'F': 0.15776081424936386,
#                                        'F - M': -0.6844783715012723})}),
#              'i.': defaultdict(None,
#                          {'counts': Counter({'M': 5, 'F': 1}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8333333333333334,
#                                        'F': 0.16666666666666666,
#                                        'F - M': -0.6666666666666667})}),
#              'retain': defaultdict(None,
#                          {'counts': Counter({'M': 9, 'F': 1}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9, 'F': 0.1, 'F - M': -0.8})}),
#              'immunity': defaultdict(None,
#                          {'counts': Counter({'M': 73, 'F': 3}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9605263157894737,
#                                        'F': 0.039473684210526314,
#                                        'F - M': -0.9210526315789473})}),
#              'avoid': defaultdict(None,
#                          {'counts': Counter({'M': 25, 'F': 5}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8333333333333334,
#                                        'F': 0.16666666666666666,
#                                        'F - M': -0.6666666666666667})}),
#              'infringing': defaultdict(None,
#                          {'counts': Counter({'M': 9, 'F': 3}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.75, 'F': 0.25, 'F - M': -0.5})}),
#              'same': defaultdict(None,
#                          {'counts': Counter({'M': 419, 'F': 74}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8498985801217038,
#                                        'F': 0.15010141987829614,
#                                        'F - M': -0.6997971602434077})}),
#              'secure': defaultdict(None,
#                          {'counts': Counter({'M': 4}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'would': defaultdict(None,
#                          {'counts': Counter({'M': 2112, 'F': 271}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8862778010910617,
#                                        'F': 0.11372219890893831,
#                                        'F - M': -0.7725556021821234})}),
#              'incompatible': defaultdict(None,
#                          {'counts': Counter({'M': 2}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'as': defaultdict(None,
#                          {'counts': Counter({'M': 1972, 'F': 191}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9116967175219602,
#                                        'F': 0.08830328247803976,
#                                        'F - M': -0.8233934350439205})}),
#              'fixed': defaultdict(None,
#                          {'counts': Counter({'M': 9}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
# ...
#              'naturally': defaultdict(None,
#                          {'counts': Counter({'M': 5}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'add': defaultdict(None,
#                          {'counts': Counter({'M': 26, 'F': 4}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8666666666666667,
#                                        'F': 0.13333333333333333,
#                                        'F - M': -0.7333333333333334})}),
#              'additional': defaultdict(None,
#                          {'counts': Counter({'M': 52, 'F': 11}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8253968253968254,
#                                        'F': 0.1746031746031746,
#                                        'F - M': -0.6507936507936507})}),
#              'element': defaultdict(None,
#                          {'counts': Counter({'M': 44, 'F': 1}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9777777777777777,
#                                        'F': 0.022222222222222223,
#                                        'F - M': -0.9555555555555555})}),
#              'complete': defaultdict(None,
#                          {'counts': Counter({'M': 25}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'features': defaultdict(None,
#                          {'counts': Counter({'M': 6}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'need': defaultdict(None,
#                          {'counts': Counter({'M': 205, 'F': 43}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8266129032258065,
#                                        'F': 0.17338709677419356,
#                                        'F - M': -0.653225806451613})}),
#              'alternative': defaultdict(None,
#                          {'counts': Counter({'M': 36, 'F': 2}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9473684210526315,
#                                        'F': 0.05263157894736842,
#                                        'F - M': -0.894736842105263})}),
#              'available': defaultdict(None,
#                          {'counts': Counter({'M': 81, 'F': 8}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9101123595505618,
#                                        'F': 0.0898876404494382,
#                                        'F - M': -0.8202247191011236})}),
#              'explicitly': defaultdict(None,
#                          {'counts': Counter({'M': 15, 'F': 2}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8823529411764706,
#                                        'F': 0.11764705882352941,
#                                        'F - M': -0.7647058823529411})}),
#              'bargained': defaultdict(None,
#                          {'counts': Counter({'M': 2}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'says': defaultdict(None,
#                          {'counts': Counter({'M': 370, 'F': 56}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8685446009389671,
#                                        'F': 0.13145539906103287,
#                                        'F - M': -0.7370892018779343})}),
#              'non': defaultdict(None,
#                          {'counts': Counter({'M': 137, 'F': 6}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.958041958041958,
#                                        'F': 0.04195804195804196,
#                                        'F - M': -0.916083916083916})}),
#              'commercial': defaultdict(None,
#                          {'counts': Counter({'M': 22, 'F': 4}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8461538461538461,
#                                        'F': 0.15384615384615385,
#                                        'F - M': -0.6923076923076923})}),
#              'purposes': defaultdict(None,
#                          {'counts': Counter({'M': 96, 'F': 10}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9056603773584906,
#                                        'F': 0.09433962264150944,
#                                        'F - M': -0.8113207547169812})}),
#              'highlights': defaultdict(None,
#                          {'counts': Counter({'M': 5}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'scope': defaultdict(None,
#                          {'counts': Counter({'M': 40, 'F': 7}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.851063829787234,
#                                        'F': 0.14893617021276595,
#                                        'F - M': -0.7021276595744681})}),
#              'contractual': defaultdict(None,
#                          {'counts': Counter({'M': 6, 'F': 2}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.75, 'F': 0.25, 'F - M': -0.5})}),
#              'license': defaultdict(None,
#                          {'counts': Counter({'M': 46, 'F': 13}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.7796610169491526,
#                                        'F': 0.22033898305084745,
#                                        'F - M': -0.5593220338983051})}),
#              'pending': defaultdict(None,
#                          {'counts': Counter({'M': 19, 'F': 1}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.95,
#                                        'F': 0.05,
#                                        'F - M': -0.8999999999999999})}),
#              'breach': defaultdict(None,
#                          {'counts': Counter({'M': 41}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'contract': defaultdict(None,
#                          {'counts': Counter({'M': 159, 'F': 13}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9244186046511628,
#                                        'F': 0.0755813953488372,
#                                        'F - M': -0.8488372093023255})}),
#              'partner': defaultdict(None,
#                          {'counts': Counter({'M': 2, 'F': 2}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.5, 'F': 0.5, 'F - M': 0.0})}),
#              'intersal': defaultdict(None,
#                          {'counts': Counter({'M': 4}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'debating': defaultdict(None,
#                          {'counts': Counter({'M': 2, 'F': 1}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.6666666666666666,
#                                        'F': 0.3333333333333333,
#                                        'F - M': -0.3333333333333333})}),
#              'exceeded': defaultdict(None,
#                          {'counts': Counter({'M': 2}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'example': defaultdict(None,
#                          {'counts': Counter({'M': 229, 'F': 38}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8576779026217228,
#                                        'F': 0.14232209737827714,
#                                        'F - M': -0.7153558052434457})}),
#              'putting': defaultdict(None,
#                          {'counts': Counter({'M': 29, 'F': 5}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8529411764705882,
#                                        'F': 0.14705882352941177,
#                                        'F - M': -0.7058823529411764})}),
#              'asserted': defaultdict(None,
#                          {'counts': Counter({'M': 15}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'affirmatively': defaultdict(None,
#                          {'counts': Counter({'M': 11, 'F': 2}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8461538461538461,
#                                        'F': 0.15384615384615385,
#                                        'F - M': -0.6923076923076923})}),
#              'waived': defaultdict(None,
#                          {'counts': Counter({'M': 12, 'F': 6}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.6666666666666666,
#                                        'F': 0.3333333333333333,
#                                        'F - M': -0.3333333333333333})}),
#              'strange': defaultdict(None,
#                          {'counts': Counter({'M': 9}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'ca': defaultdict(None,
#                          {'counts': Counter({'M': 210, 'F': 47}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8171206225680934,
#                                        'F': 0.1828793774319066,
#                                        'F - M': -0.6342412451361867})}),
#              'possibly': defaultdict(None,
#                          {'counts': Counter({'M': 19, 'F': 1}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.95,
#                                        'F': 0.05,
#                                        'F - M': -0.8999999999999999})}),
#              'relevance': defaultdict(None,
#                          {'counts': Counter({'M': 5}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'alleged': defaultdict(None,
#                          {'counts': Counter({'M': 35, 'F': 3}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9210526315789473,
#                                        'F': 0.07894736842105263,
#                                        'F - M': -0.8421052631578947})}),
#              'exposes': defaultdict(None,
#                          {'counts': Counter({'M': 4}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'second': defaultdict(None,
#                          {'counts': Counter({'M': 298, 'F': 47}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.863768115942029,
#                                        'F': 0.13623188405797101,
#                                        'F - M': -0.7275362318840579})}),
#              'types': defaultdict(None,
#                          {'counts': Counter({'M': 30, 'F': 14}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.6818181818181818,
#                                        'F': 0.3181818181818182,
#                                        'F - M': -0.3636363636363636})}),
#              'related': defaultdict(None,
#                          {'counts': Counter({'M': 44, 'F': 2}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9565217391304348,
#                                        'F': 0.043478260869565216,
#                                        'F - M': -0.9130434782608696})}),
#              'declaratory': defaultdict(None,
#                          {'counts': Counter({'M': 10}),
#                           'ratio': defaultdict(None,
#                                       {'M': 1.0, 'F': 0.0, 'F - M': -1.0})}),
#              'declared': defaultdict(None,
#                          {'counts': Counter({'M': 3, 'F': 1}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.75, 'F': 0.25, 'F - M': -0.5})}),
#              'preempted': defaultdict(None,
#                          {'counts': Counter({'M': 11, 'F': 1}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9166666666666666,
#                                        'F': 0.08333333333333333,
#                                        'F - M': -0.8333333333333333})}),
#              'sought': defaultdict(None,
#                          {'counts': Counter({'M': 30, 'F': 3}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.9090909090909091,
#                                        'F': 0.09090909090909091,
#                                        'F - M': -0.8181818181818181})}),
#              'cert': defaultdict(None,
#                          {'counts': Counter({'M': 27, 'F': 6}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8181818181818182,
#                                        'F': 0.18181818181818182,
#                                        'F - M': -0.6363636363636365})}),
#              'circumstance': defaultdict(None,
#                          {'counts': Counter({'M': 64, 'F': 9}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8767123287671232,
#                                        'F': 0.1232876712328767,
#                                        'F - M': -0.7534246575342465})}),
#              'district': defaultdict(None,
#                          {'counts': Counter({'M': 243, 'F': 74}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.7665615141955836,
#                                        'F': 0.2334384858044164,
#                                        'F - M': -0.5331230283911672})}),
#              'fourth': defaultdict(None,
#                          {'counts': Counter({'M': 47, 'F': 11}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8103448275862069,
#                                        'F': 0.1896551724137931,
#                                        'F - M': -0.6206896551724137})}),
#              'pages': defaultdict(None,
#                          {'counts': Counter({'M': 45, 'F': 8}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.8490566037735849,
#                                        'F': 0.1509433962264151,
#                                        'F - M': -0.6981132075471699})}),
#              'appendix': defaultdict(None,
#                          {'counts': Counter({'M': 48, 'F': 15}),
#                           'ratio': defaultdict(None,
#                                       {'M': 0.7619047619047619,
#                                        'F': 0.23809523809523808,
#                                        'F - M': -0.5238095238095237})}),
#              ...})
