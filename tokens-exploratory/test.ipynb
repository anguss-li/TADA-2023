# %%
from typing import Dict, Iterable, List, Tuple
from convokit import Corpus, Speaker, Utterance, download
from collections import defaultdict, Counter
import numpy as np

# %%
corpus = Corpus(filename="../supreme_processed")

# Filter out speakers without gender signal
corpus = corpus.filter_utterances_by(
    lambda utt: utt.get_speaker().retrieve_meta("gender_signal") != None
)

# %%
# Our goal is to build a table with each word token in the vocabulary for the Supreme Court corpus, 
# listing the number of male and female speakers as well as some percentages.
counts = defaultdict(Counter)
# keys: tokens in the vocabulary
# values: Counter dictionaries 
#   keys: str, gender signals
#   values: how many speakers of given gender have said the token

"""Flattens the "tokens" dictionary of an Utterance into a list."""
def get_tokens(utt: Utterance) -> List[str]:
    return [tok["tok"]
            for sent in utt.retrieve_meta("tokens")
            for tok in sent["toks"]]

for utt in corpus.iter_utterances():
    tokens = get_tokens(utt)
    gender = utt.get_speaker().retrieve_meta("gender_signal")
    for token in tokens:
        counts[token][gender] += 1

# Add percentages in a second run because this is a bit neater.
table = defaultdict(defaultdict)
# keys: tokens in the vocabulary
# values: default dicts 
#   keys: str, counts and ratios for male and female speakers
#   values: int/floats 

for token in counts: 
    table[token]["M count"] = counts[token]["M"]
    table[token]["F count"] = counts[token]["F"]
    table[token]["total"] = table[token]["M count"] + table[token]["F count"]
    
    table[token]["M ratio"] = table[token]["M count"] / table[token]["total"]
    table[token]["F ratio"] = table[token]["F count"] / table[token]["total"]
    table[token]["F - M"] = table[token]["F ratio"] - table[token]["M ratio"]

# The total number of times a token is used, summed for all tokens in V
total_vocab_usage = sum(table[token]["total"] for token in table)
# The total number of times a token is used by a female speaker, summed for all tokens in V
female_total_vocab_usage = sum(table[token]["F count"] for token in table)
# The proportion of all token usage in the corpus done by female speakers
p_j = female_total_vocab_usage / total_vocab_usage

for token in table:
    # The proportion of all token usage in the corpus taken up by this specific token
    p_i = table[token]["total"] / total_vocab_usage
    # The proportion of all token usage in the corpus taken up by this specific token,
    # and where the speaker is female
    p_ij = table[token]["F count"] / total_vocab_usage
    # The positive pointwise mutual information (PMI) between:
    #   i: the event this token is used
    #   j: the event a female speaker speakuses a words (uses a word in V)
    PPMI = max(np.log2(p_ij / (p_i * p_j)), 0) if p_ij != 0 else 0
    table[token]["PPMI"] = PPMI

table
# Out:
# defaultdict(collections.defaultdict,
#             {'mr': defaultdict(None,
#                          {'M count': 353,
#                           'F count': 52,
#                           'total': 405,
#                           'M ratio': 0.8716049382716049,
#                           'F ratio': 0.12839506172839507,
#                           'F - M': -0.7432098765432098,
#                           'PPMI': 0.03980811972417442}),
#              '.': defaultdict(None,
#                          {'M count': 14717,
#                           'F count': 2273,
#                           'total': 16990,
#                           'M ratio': 0.8662154208357857,
#                           'F ratio': 0.13378457916421424,
#                           'F - M': -0.7324308416715715,
#                           'PPMI': 0.09913023610133405}),
#              'chief': defaultdict(None,
#                          {'M count': 245,
#                           'F count': 40,
#                           'total': 285,
#                           'M ratio': 0.8596491228070176,
#                           'F ratio': 0.14035087719298245,
#                           'F - M': -0.7192982456140351,
#                           'PPMI': 0.16825648519032746}),
#              'justice': defaultdict(None,
#                          {'M count': 962,
#                           'F count': 149,
#                           'total': 1111,
#                           'M ratio': 0.8658865886588659,
#                           'F ratio': 0.1341134113411341,
#                           'F - M': -0.7317731773177318,
#                           'PPMI': 0.10267191842813876}),
#              ',': defaultdict(None,
#                          {'M count': 19757,
#                           'F count': 2859,
#                           'total': 22616,
#                           'M ratio': 0.8735850725150336,
#                           'F ratio': 0.12641492748496638,
#                           'F - M': -0.7471701450300672,
#                           'PPMI': 0.01738523615499206}),
#              'and': defaultdict(None,
#                          {'M count': 8012,
#                           'F count': 1228,
#                           'total': 9240,
#                           'M ratio': 0.8670995670995671,
#                           'F ratio': 0.1329004329004329,
#                           'F - M': -0.7341991341991343,
#                           'PPMI': 0.0895642084218286}),
#              'may': defaultdict(None,
#                          {'M count': 363,
#                           'F count': 58,
#                           'total': 421,
#                           'M ratio': 0.8622327790973872,
#                           'F ratio': 0.1377672209026128,
#                           'F - M': -0.7244655581947743,
#                           'PPMI': 0.1414510714162456}),
#              'it': defaultdict(None,
#                          {'M count': 5769,
#                           'F count': 906,
#                           'total': 6675,
#                           'M ratio': 0.8642696629213483,
#                           'F ratio': 0.13573033707865167,
#                           'F - M': -0.7285393258426967,
#                           'PPMI': 0.11996161793902586}),
#              'please': defaultdict(None,
#                          {'M count': 133,
#                           'F count': 21,
#                           'total': 154,
#                           'M ratio': 0.8636363636363636,
#                           'F ratio': 0.13636363636363635,
#                           'F - M': -0.7272727272727273,
#                           'PPMI': 0.12667738143892832}),
#              'the': defaultdict(None,
#                          {'M count': 22049,
#                           'F count': 2563,
#                           'total': 24612,
#                           'M ratio': 0.8958638062733626,
#                           'F ratio': 0.10413619372663742,
#                           'F - M': -0.7917276125467252,
#                           'PPMI': 0}),
#              'court': defaultdict(None,
#                          {'M count': 2401,
#                           'F count': 349,
#                           'total': 2750,
#                           'M ratio': 0.8730909090909091,
#                           'F ratio': 0.12690909090909092,
#                           'F - M': -0.7461818181818183,
#                           'PPMI': 0.02301382226533734}),
#              ':': defaultdict(None,
#                          {'M count': 268,
#                           'F count': 42,
#                           'total': 310,
#                           'M ratio': 0.864516129032258,
#                           'F ratio': 0.13548387096774195,
#                           'F - M': -0.7290322580645161,
#                           'PPMI': 0.11733951685959197}),
#              'when': defaultdict(None,
#                          {'M count': 673,
#                           'F count': 96,
#                           'total': 769,
#                           'M ratio': 0.8751625487646294,
#                           'F ratio': 0.12483745123537061,
#                           'F - M': -0.7503250975292588,
#                           'PPMI': 0}),
#              'states': defaultdict(None,
#                          {'M count': 371,
#                           'F count': 32,
#                           'total': 403,
#                           'M ratio': 0.9205955334987593,
#                           'F ratio': 0.0794044665012407,
#                           'F - M': -0.8411910669975187,
#                           'PPMI': 0}),
#              'infringe': defaultdict(None,
#                          {'M count': 9,
#                           'F count': 1,
#                           'total': 10,
#                           'M ratio': 0.9,
#                           'F ratio': 0.1,
#                           'F - M': -0.8,
#                           'PPMI': 0}),
#              'exclusive': defaultdict(None,
#                          {'M count': 19,
#                           'F count': 0,
#                           'total': 19,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'federal': defaultdict(None,
#                          {'M count': 418,
#                           'F count': 29,
#                           'total': 447,
#                           'M ratio': 0.9351230425055929,
#                           'F ratio': 0.06487695749440715,
#                           'F - M': -0.8702460850111857,
#                           'PPMI': 0}),
#              'rights': defaultdict(None,
#                          {'M count': 147,
#                           'F count': 9,
#                           'total': 156,
#                           'M ratio': 0.9423076923076923,
#                           'F ratio': 0.057692307692307696,
#                           'F - M': -0.8846153846153846,
#                           'PPMI': 0}),
#              'that': defaultdict(None,
#                          {'M count': 12310,
#                           'F count': 1745,
#                           'total': 14055,
#                           'M ratio': 0.8758448950551405,
#                           'F ratio': 0.12415510494485948,
#                           'F - M': -0.751689790110281,
#                           'PPMI': 0}),
#              'congress': defaultdict(None,
#                          {'M count': 1010,
#                           'F count': 31,
#                           'total': 1041,
#                           'M ratio': 0.9702209414024976,
#                           'F ratio': 0.029779058597502402,
#                           'F - M': -0.9404418828049952,
#                           'PPMI': 0}),
#              'is': defaultdict(None,
#                          {'M count': 5953,
#                           'F count': 891,
#                           'total': 6844,
#                           'M ratio': 0.869812974868498,
#                           'F ratio': 0.13018702513150204,
#                           'F - M': -0.7396259497369959,
#                           'PPMI': 0.059804076387577454}),
#              'charged': defaultdict(None,
#                          {'M count': 17,
#                           'F count': 1,
#                           'total': 18,
#                           'M ratio': 0.9444444444444444,
#                           'F ratio': 0.05555555555555555,
#                           'F - M': -0.8888888888888888,
#                           'PPMI': 0}),
#              'with': defaultdict(None,
#                          {'M count': 1518,
#                           'F count': 177,
#                           'total': 1695,
#                           'M ratio': 0.8955752212389381,
#                           'F ratio': 0.10442477876106195,
#                           'F - M': -0.7911504424778761,
#                           'PPMI': 0}),
#              'securing': defaultdict(None,
#                          {'M count': 3,
#                           'F count': 1,
#                           'total': 4,
#                           'M ratio': 0.75,
#                           'F ratio': 0.25,
#                           'F - M': -0.5,
#                           'PPMI': 1.0011464993550694}),
#              'can': defaultdict(None,
#                          {'M count': 777,
#                           'F count': 128,
#                           'total': 905,
#                           'M ratio': 0.8585635359116022,
#                           'F ratio': 0.1414364640883978,
#                           'F - M': -0.7171270718232043,
#                           'PPMI': 0.17937251738450147}),
#              'make': defaultdict(None,
#                          {'M count': 415,
#                           'F count': 49,
#                           'total': 464,
#                           'M ratio': 0.8943965517241379,
#                           'F ratio': 0.10560344827586207,
#                           'F - M': -0.7887931034482758,
#                           'PPMI': 0}),
#              'pay': defaultdict(None,
#                          {'M count': 127,
#                           'F count': 6,
#                           'total': 133,
#                           'M ratio': 0.9548872180451128,
#                           'F ratio': 0.045112781954887216,
#                           'F - M': -0.9097744360902256,
#                           'PPMI': 0}),
#              'for': defaultdict(None,
#                          {'M count': 2306,
#                           'F count': 282,
#                           'total': 2588,
#                           'M ratio': 0.8910355486862442,
#                           'F ratio': 0.10896445131375579,
#                           'F - M': -0.7820710973724885,
#                           'PPMI': 0}),
#              'doing': defaultdict(None,
#                          {'M count': 151,
#                           'F count': 10,
#                           'total': 161,
#                           'M ratio': 0.937888198757764,
#                           'F ratio': 0.062111801242236024,
#                           'F - M': -0.8757763975155279,
#                           'PPMI': 0}),
#              'so': defaultdict(None,
#                          {'M count': 1837,
#                           'F count': 401,
#                           'total': 2238,
#                           'M ratio': 0.8208221626452189,
#                           'F ratio': 0.17917783735478104,
#                           'F - M': -0.6416443252904378,
#                           'PPMI': 0.5206106048335954}),
#              "'s": defaultdict(None,
#                          {'M count': 5225,
#                           'F count': 802,
#                           'total': 6027,
#                           'M ratio': 0.8669321387091422,
#                           'F ratio': 0.13306786129085782,
#                           'F - M': -0.7338642774182844,
#                           'PPMI': 0.09138057635554132}),
#              'our': defaultdict(None,
#                          {'M count': 586,
#                           'F count': 78,
#                           'total': 664,
#                           'M ratio': 0.8825301204819277,
#                           'F ratio': 0.11746987951807229,
#                           'F - M': -0.7650602409638554,
#                           'PPMI': 0}),
#              'respectful': defaultdict(None,
#                          {'M count': 5,
#                           'F count': 0,
#                           'total': 5,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'submission': defaultdict(None,
#                          {'M count': 25,
#                           'F count': 0,
#                           'total': 25,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'today': defaultdict(None,
#                          {'M count': 80,
#                           'F count': 19,
#                           'total': 99,
#                           'M ratio': 0.8080808080808081,
#                           'F ratio': 0.1919191919191919,
#                           'F - M': -0.6161616161616161,
#                           'PPMI': 0.6197173927190449}),
#              'one': defaultdict(None,
#                          {'M count': 836,
#                           'F count': 130,
#                           'total': 966,
#                           'M ratio': 0.865424430641822,
#                           'F ratio': 0.13457556935817805,
#                           'F - M': -0.7308488612836439,
#                           'PPMI': 0.10763493354775072}),
#              'follows': defaultdict(None,
#                          {'M count': 14,
#                           'F count': 2,
#                           'total': 16,
#                           'M ratio': 0.875,
#                           'F ratio': 0.125,
#                           'F - M': -0.75,
#                           'PPMI': 0.001146499355069386}),
#              'from': defaultdict(None,
#                          {'M count': 891,
#                           'F count': 101,
#                           'total': 992,
#                           'M ratio': 0.8981854838709677,
#                           'F ratio': 0.10181451612903226,
#                           'F - M': -0.7963709677419355,
#                           'PPMI': 0}),
#              'constitution': defaultdict(None,
#                          {'M count': 107,
#                           'F count': 2,
#                           'total': 109,
#                           'M ratio': 0.981651376146789,
#                           'F ratio': 0.01834862385321101,
#                           'F - M': -0.963302752293578,
#                           'PPMI': 0}),
#              'text': defaultdict(None,
#                          {'M count': 183,
#                           'F count': 5,
#                           'total': 188,
#                           'M ratio': 0.973404255319149,
#                           'F ratio': 0.026595744680851064,
#                           'F - M': -0.946808510638298,
#                           'PPMI': 0}),
#              'affords': defaultdict(None,
#                          {'M count': 3,
#                           'F count': 0,
#                           'total': 3,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'ample': defaultdict(None,
#                          {'M count': 6,
#                           'F count': 0,
#                           'total': 6,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'basis': defaultdict(None,
#                          {'M count': 136,
#                           'F count': 14,
#                           'total': 150,
#                           'M ratio': 0.9066666666666666,
#                           'F ratio': 0.09333333333333334,
#                           'F - M': -0.8133333333333332,
#                           'PPMI': 0}),
#              'this': defaultdict(None,
#                          {'M count': 3116,
#                           'F count': 454,
#                           'total': 3570,
#                           'M ratio': 0.8728291316526611,
#                           'F ratio': 0.12717086834733893,
#                           'F - M': -0.7456582633053221,
#                           'PPMI': 0.025986627729522416}),
#              'to': defaultdict(None,
#                          {'M count': 9580,
#                           'F count': 1249,
#                           'total': 10829,
#                           'M ratio': 0.8846615569304644,
#                           'F ratio': 0.1153384430695355,
#                           'F - M': -0.7693231138609289,
#                           'PPMI': 0}),
#              'uphold': defaultdict(None,
#                          {'M count': 9,
#                           'F count': 0,
#                           'total': 9,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'work': defaultdict(None,
#                          {'M count': 131,
#                           'F count': 8,
#                           'total': 139,
#                           'M ratio': 0.9424460431654677,
#                           'F ratio': 0.05755395683453238,
#                           'F - M': -0.8848920863309353,
#                           'PPMI': 0}),
#              'did': defaultdict(None,
#                          {'M count': 671,
#                           'F count': 87,
#                           'total': 758,
#                           'M ratio': 0.8852242744063324,
#                           'F ratio': 0.11477572559366754,
#                           'F - M': -0.7704485488126649,
#                           'PPMI': 0}),
#              'in': defaultdict(None,
#                          {'M count': 6194,
#                           'F count': 800,
#                           'total': 6994,
#                           'M ratio': 0.885616242493566,
#                           'F ratio': 0.11438375750643409,
#                           'F - M': -0.7712324849871319,
#                           'PPMI': 0}),
#              'enacting': defaultdict(None,
#                          {'M count': 11,
#                           'F count': 0,
#                           'total': 11,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'crca': defaultdict(None,
#                          {'M count': 13,
#                           'F count': 0,
#                           'total': 13,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'article': defaultdict(None,
#                          {'M count': 150,
#                           'F count': 0,
#                           'total': 150,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'i': defaultdict(None,
#                          {'M count': 5570,
#                           'F count': 700,
#                           'total': 6270,
#                           'M ratio': 0.8883572567783095,
#                           'F ratio': 0.11164274322169059,
#                           'F - M': -0.7767145135566189,
#                           'PPMI': 0}),
#              'section': defaultdict(None,
#                          {'M count': 295,
#                           'F count': 43,
#                           'total': 338,
#                           'M ratio': 0.8727810650887574,
#                           'F ratio': 0.12721893491124261,
#                           'F - M': -0.7455621301775148,
#                           'PPMI': 0.02653181777498282}),
#              '<': defaultdict(None,
#                          {'M count': 1864,
#                           'F count': 258,
#                           'total': 2122,
#                           'M ratio': 0.8784165881244109,
#                           'F ratio': 0.12158341187558906,
#                           'F - M': -0.7568331762488218,
#                           'PPMI': 0}),
#              'number': defaultdict(None,
#                          {'M count': 1504,
#                           'F count': 220,
#                           'total': 1724,
#                           'M ratio': 0.8723897911832946,
#                           'F ratio': 0.12761020881670534,
#                           'F - M': -0.7447795823665893,
#                           'PPMI': 0.030962153790630706}),
#              '>': defaultdict(None,
#                          {'M count': 1586,
#                           'F count': 229,
#                           'total': 1815,
#                           'M ratio': 0.8738292011019284,
#                           'F ratio': 0.12617079889807162,
#                           'F - M': -0.7476584022038568,
#                           'PPMI': 0.014596454568900177}),
#              'clause': defaultdict(None,
#                          {'M count': 181,
#                           'F count': 11,
#                           'total': 192,
#                           'M ratio': 0.9427083333333334,
#                           'F ratio': 0.057291666666666664,
#                           'F - M': -0.8854166666666667,
#                           'PPMI': 0}),
#              'what': defaultdict(None,
#                          {'M count': 1576,
#                           'F count': 221,
#                           'total': 1797,
#                           'M ratio': 0.8770172509738453,
#                           'F ratio': 0.1229827490261547,
#                           'F - M': -0.7540345019476906,
#                           'PPMI': 0}),
#              'we': defaultdict(None,
#                          {'M count': 2476,
#                           'F count': 349,
#                           'total': 2825,
#                           'M ratio': 0.8764601769911504,
#                           'F ratio': 0.12353982300884955,
#                           'F - M': -0.7529203539823008,
#                           'PPMI': 0}),
#              "'re": defaultdict(None,
#                          {'M count': 969,
#                           'F count': 137,
#                           'total': 1106,
#                           'M ratio': 0.8761301989150091,
#                           'F ratio': 0.12386980108499096,
#                           'F - M': -0.7522603978300182,
#                           'PPMI': 0}),
#              'calling': defaultdict(None,
#                          {'M count': 11,
#                           'F count': 2,
#                           'total': 13,
#                           'M ratio': 0.8461538461538461,
#                           'F ratio': 0.15384615384615385,
#                           'F - M': -0.6923076923076923,
#                           'PPMI': 0.30070678121397704}),
#              'intellectual': defaultdict(None,
#                          {'M count': 6,
#                           'F count': 0,
#                           'total': 6,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'property': defaultdict(None,
#                          {'M count': 172,
#                           'F count': 5,
#                           'total': 177,
#                           'M ratio': 0.9717514124293786,
#                           'F ratio': 0.02824858757062147,
#                           'F - M': -0.9435028248587571,
#                           'PPMI': 0}),
#              'unique': defaultdict(None,
#                          {'M count': 20,
#                           'F count': 5,
#                           'total': 25,
#                           'M ratio': 0.8,
#                           'F ratio': 0.2,
#                           'F - M': -0.6000000000000001,
#                           'PPMI': 0.6792184044677068}),
#              'within': defaultdict(None,
#                          {'M count': 157,
#                           'F count': 6,
#                           'total': 163,
#                           'M ratio': 0.9631901840490797,
#                           'F ratio': 0.03680981595092025,
#                           'F - M': -0.9263803680981595,
#                           'PPMI': 0}),
#              'laying': defaultdict(None,
#                          {'M count': 3,
#                           'F count': 0,
#                           'total': 3,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'down': defaultdict(None,
#                          {'M count': 94,
#                           'F count': 11,
#                           'total': 105,
#                           'M ratio': 0.8952380952380953,
#                           'F ratio': 0.10476190476190476,
#                           'F - M': -0.7904761904761906,
#                           'PPMI': 0}),
#              'an': defaultdict(None,
#                          {'M count': 1356,
#                           'F count': 180,
#                           'total': 1536,
#                           'M ratio': 0.8828125,
#                           'F ratio': 0.1171875,
#                           'F - M': -0.765625,
#                           'PPMI': 0}),
#              'express': defaultdict(None,
#                          {'M count': 32,
#                           'F count': 2,
#                           'total': 34,
#                           'M ratio': 0.9411764705882353,
#                           'F ratio': 0.058823529411764705,
#                           'F - M': -0.8823529411764706,
#                           'PPMI': 0}),
#              'constitutional': defaultdict(None,
#                          {'M count': 170,
#                           'F count': 14,
#                           'total': 184,
#                           'M ratio': 0.9239130434782609,
#                           'F ratio': 0.07608695652173914,
#                           'F - M': -0.8478260869565217,
#                           'PPMI': 0}),
#              'mandate': defaultdict(None,
#                          {'M count': 28,
#                           'F count': 1,
#                           'total': 29,
#                           'M ratio': 0.9655172413793104,
#                           'F ratio': 0.034482758620689655,
#                           'F - M': -0.9310344827586208,
#                           'PPMI': 0}),
#              'protect': defaultdict(None,
#                          {'M count': 45,
#                           'F count': 9,
#                           'total': 54,
#                           'M ratio': 0.8333333333333334,
#                           'F ratio': 0.16666666666666666,
#                           'F - M': -0.6666666666666667,
#                           'PPMI': 0.41618399863391287}),
#              'specified': defaultdict(None,
#                          {'M count': 16,
#                           'F count': 0,
#                           'total': 16,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'private': defaultdict(None,
#                          {'M count': 109,
#                           'F count': 2,
#                           'total': 111,
#                           'M ratio': 0.9819819819819819,
#                           'F ratio': 0.018018018018018018,
#                           'F - M': -0.9639639639639639,
#                           'PPMI': 0}),
#              'against': defaultdict(None,
#                          {'M count': 185,
#                           'F count': 36,
#                           'total': 221,
#                           'M ratio': 0.8371040723981901,
#                           'F ratio': 0.16289592760180996,
#                           'F - M': -0.6742081447963801,
#                           'PPMI': 0.38316894140595026}),
#              'any': defaultdict(None,
#                          {'M count': 630,
#                           'F count': 80,
#                           'total': 710,
#                           'M ratio': 0.8873239436619719,
#                           'F ratio': 0.11267605633802817,
#                           'F - M': -0.7746478873239437,
#                           'PPMI': 0}),
#              'all': defaultdict(None,
#                          {'M count': 974,
#                           'F count': 117,
#                           'total': 1091,
#                           'M ratio': 0.8927589367552704,
#                           'F ratio': 0.10724106324472961,
#                           'F - M': -0.7855178735105408,
#                           'PPMI': 0}),
#              'intrusion': defaultdict(None,
#                          {'M count': 6,
#                           'F count': 0,
#                           'total': 6,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'consider': defaultdict(None,
#                          {'M count': 59,
#                           'F count': 21,
#                           'total': 80,
#                           'M ratio': 0.7375,
#                           'F ratio': 0.2625,
#                           'F - M': -0.47500000000000003,
#                           'PPMI': 1.0715358272464672}),
#              'just': defaultdict(None,
#                          {'M count': 840,
#                           'F count': 195,
#                           'total': 1035,
#                           'M ratio': 0.8115942028985508,
#                           'F ratio': 0.18840579710144928,
#                           'F - M': -0.6231884057971016,
#                           'PPMI': 0.5930617607179923}),
#              'how': defaultdict(None,
#                          {'M count': 328,
#                           'F count': 55,
#                           'total': 383,
#                           'M ratio': 0.856396866840731,
#                           'F ratio': 0.14360313315926893,
#                           'F - M': -0.712793733681462,
#                           'PPMI': 0.20130563095477186}),
#              'pointed': defaultdict(None,
#                          {'M count': 62,
#                           'F count': 9,
#                           'total': 71,
#                           'M ratio': 0.8732394366197183,
#                           'F ratio': 0.1267605633802817,
#                           'F - M': -0.7464788732394365,
#                           'PPMI': 0.02132438129269952}),
#              'clear': defaultdict(None,
#                          {'M count': 338,
#                           'F count': 59,
#                           'total': 397,
#                           'M ratio': 0.8513853904282116,
#                           'F ratio': 0.1486146095717884,
#                           'F - M': -0.7027707808564232,
#                           'PPMI': 0.2507943515739529}),
#              'not': defaultdict(None,
#                          {'M count': 2873,
#                           'F count': 428,
#                           'total': 3301,
#                           'M ratio': 0.8703423205089367,
#                           'F ratio': 0.12965767949106333,
#                           'F - M': -0.7406846410178733,
#                           'PPMI': 0.053926062533680104}),
#              'only': defaultdict(None,
#                          {'M count': 435,
#                           'F count': 70,
#                           'total': 505,
#                           'M ratio': 0.8613861386138614,
#                           'F ratio': 0.13861386138613863,
#                           'F - M': -0.7227722772277227,
#                           'PPMI': 0.15028993866087867}),
#              'be': defaultdict(None,
#                          {'M count': 2385,
#                           'F count': 285,
#                           'total': 2670,
#                           'M ratio': 0.8932584269662921,
#                           'F ratio': 0.10674157303370786,
#                           'F - M': -0.7865168539325842,
#                           'PPMI': 0}),
#              'granting': defaultdict(None,
#                          {'M count': 15,
#                           'F count': 1,
#                           'total': 16,
#                           'M ratio': 0.9375,
#                           'F ratio': 0.0625,
#                           'F - M': -0.875,
#                           'PPMI': 0}),
#              'copyrights': defaultdict(None,
#                          {'M count': 19,
#                           'F count': 0,
#                           'total': 19,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'but': defaultdict(None,
#                          {'M count': 1968,
#                           'F count': 309,
#                           'total': 2277,
#                           'M ratio': 0.8642951251646904,
#                           'F ratio': 0.13570487483530963,
#                           'F - M': -0.7285902503293809,
#                           'PPMI': 0.1196909511228216}),
#              'them': defaultdict(None,
#                          {'M count': 345,
#                           'F count': 48,
#                           'total': 393,
#                           'M ratio': 0.8778625954198473,
#                           'F ratio': 0.12213740458015267,
#                           'F - M': -0.7557251908396947,
#                           'PPMI': 0}),
#              'resulting': defaultdict(None,
#                          {'M count': 4,
#                           'F count': 1,
#                           'total': 5,
#                           'M ratio': 0.8,
#                           'F ratio': 0.2,
#                           'F - M': -0.6000000000000001,
#                           'PPMI': 0.6792184044677068}),
#              'by': defaultdict(None,
#                          {'M count': 953,
#                           'F count': 99,
#                           'total': 1052,
#                           'M ratio': 0.905893536121673,
#                           'F ratio': 0.094106463878327,
#                           'F - M': -0.811787072243346,
#                           'PPMI': 0}),
#              'definition': defaultdict(None,
#                          {'M count': 59,
#                           'F count': 5,
#                           'total': 64,
#                           'M ratio': 0.921875,
#                           'F ratio': 0.078125,
#                           'F - M': -0.84375,
#                           'PPMI': 0}),
#              'are': defaultdict(None,
#                          {'M count': 1755,
#                           'F count': 269,
#                           'total': 2024,
#                           'M ratio': 0.8670948616600791,
#                           'F ratio': 0.13290513833992096,
#                           'F - M': -0.7341897233201582,
#                           'PPMI': 0.08961528721738322}),
#              'meant': defaultdict(None,
#                          {'M count': 43,
#                           'F count': 3,
#                           'total': 46,
#                           'M ratio': 0.9347826086956522,
#                           'F ratio': 0.06521739130434782,
#                           'F - M': -0.8695652173913044,
#                           'PPMI': 0}),
#              'whom': defaultdict(None,
#                          {'M count': 13,
#                           'F count': 3,
#                           'total': 16,
#                           'M ratio': 0.8125,
#                           'F ratio': 0.1875,
#                           'F - M': -0.625,
#                           'PPMI': 0.5861090000762255}),
#              'your': defaultdict(None,
#                          {'M count': 952,
#                           'F count': 120,
#                           'total': 1072,
#                           'M ratio': 0.8880597014925373,
#                           'F ratio': 0.11194029850746269,
#                           'F - M': -0.7761194029850746,
#                           'PPMI': 0}),
#              'honors': defaultdict(None,
#                          {'M count': 18,
#                           'F count': 1,
#                           'total': 19,
#                           'M ratio': 0.9473684210526315,
#                           'F ratio': 0.05263157894736842,
#                           'F - M': -0.894736842105263,
#                           'PPMI': 0}),
#              '?': defaultdict(None,
#                          {'M count': 327,
#                           'F count': 53,
#                           'total': 380,
#                           'M ratio': 0.8605263157894737,
#                           'F ratio': 0.1394736842105263,
#                           'F - M': -0.7210526315789474,
#                           'PPMI': 0.15921134558732067}),
#              'comers': defaultdict(None,
#                          {'M count': 1,
#                           'F count': 0,
#                           'total': 1,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'world': defaultdict(None,
#                          {'M count': 33,
#                           'F count': 12,
#                           'total': 45,
#                           'M ratio': 0.7333333333333333,
#                           'F ratio': 0.26666666666666666,
#                           'F - M': -0.4666666666666666,
#                           'PPMI': 1.0942559037465507}),
#              'including': defaultdict(None,
#                          {'M count': 89,
#                           'F count': 17,
#                           'total': 106,
#                           'M ratio': 0.839622641509434,
#                           'F ratio': 0.16037735849056603,
#                           'F - M': -0.679245283018868,
#                           'PPMI': 0.36068888604220933}),
#              'government': defaultdict(None,
#                          {'M count': 605,
#                           'F count': 32,
#                           'total': 637,
#                           'M ratio': 0.9497645211930926,
#                           'F ratio': 0.05023547880690738,
#                           'F - M': -0.8995290423861853,
#                           'PPMI': 0}),
#              'exercise': defaultdict(None,
#                          {'M count': 87,
#                           'F count': 2,
#                           'total': 89,
#                           'M ratio': 0.9775280898876404,
#                           'F ratio': 0.02247191011235955,
#                           'F - M': -0.9550561797752808,
#                           'PPMI': 0}),
#              'of': defaultdict(None,
#                          {'M count': 8056,
#                           'F count': 1077,
#                           'total': 9133,
#                           'M ratio': 0.8820759881747509,
#                           'F ratio': 0.1179240118252491,
#                           'F - M': -0.7641519763495017,
#                           'PPMI': 0}),
#              'congressional': defaultdict(None,
#                          {'M count': 39,
#                           'F count': 4,
#                           'total': 43,
#                           'M ratio': 0.9069767441860465,
#                           'F ratio': 0.09302325581395349,
#                           'F - M': -0.8139534883720929,
#                           'PPMI': 0}),
#              'power': defaultdict(None,
#                          {'M count': 199,
#                           'F count': 5,
#                           'total': 204,
#                           'M ratio': 0.9754901960784313,
#                           'F ratio': 0.024509803921568627,
#                           'F - M': -0.9509803921568627,
#                           'PPMI': 0}),
#              'serves': defaultdict(None,
#                          {'M count': 5,
#                           'F count': 2,
#                           'total': 7,
#                           'M ratio': 0.7142857142857143,
#                           'F ratio': 0.2857142857142857,
#                           'F - M': -0.4285714285714286,
#                           'PPMI': 1.193791577297465}),
#              'purpose': defaultdict(None,
#                          {'M count': 83,
#                           'F count': 1,
#                           'total': 84,
#                           'M ratio': 0.9880952380952381,
#                           'F ratio': 0.011904761904761904,
#                           'F - M': -0.9761904761904763,
#                           'PPMI': 0}),
#              'promote': defaultdict(None,
#                          {'M count': 6,
#                           'F count': 0,
#                           'total': 6,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'progress': defaultdict(None,
#                          {'M count': 6,
#                           'F count': 0,
#                           'total': 6,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'affording': defaultdict(None,
#                          {'M count': 3,
#                           'F count': 0,
#                           'total': 3,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'monetary': defaultdict(None,
#                          {'M count': 9,
#                           'F count': 6,
#                           'total': 15,
#                           'M ratio': 0.6,
#                           'F ratio': 0.4,
#                           'F - M': -0.19999999999999996,
#                           'PPMI': 1.6792184044677068}),
#              'recompense': defaultdict(None,
#                          {'M count': 1,
#                           'F count': 0,
#                           'total': 1,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'copyright': defaultdict(None,
#                          {'M count': 108,
#                           'F count': 1,
#                           'total': 109,
#                           'M ratio': 0.9908256880733946,
#                           'F ratio': 0.009174311926605505,
#                           'F - M': -0.9816513761467891,
#                           'PPMI': 0}),
#              'holders': defaultdict(None,
#                          {'M count': 17,
#                           'F count': 0,
#                           'total': 17,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'framers': defaultdict(None,
#                          {'M count': 26,
#                           'F count': 0,
#                           'total': 26,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'thus': defaultdict(None,
#                          {'M count': 13,
#                           'F count': 5,
#                           'total': 18,
#                           'M ratio': 0.7222222222222222,
#                           'F ratio': 0.2777777777777778,
#                           'F - M': -0.4444444444444444,
#                           'PPMI': 1.153149592800119}),
#              'made': defaultdict(None,
#                          {'M count': 275,
#                           'F count': 28,
#                           'total': 303,
#                           'M ratio': 0.9075907590759076,
#                           'F ratio': 0.0924092409240924,
#                           'F - M': -0.8151815181518152,
#                           'PPMI': 0}),
#              'very': defaultdict(None,
#                          {'M count': 466,
#                           'F count': 70,
#                           'total': 536,
#                           'M ratio': 0.8694029850746269,
#                           'F ratio': 0.13059701492537312,
#                           'F - M': -0.7388059701492538,
#                           'PPMI': 0.06434032584226347}),
#              'those': defaultdict(None,
#                          {'M count': 749,
#                           'F count': 96,
#                           'total': 845,
#                           'M ratio': 0.8863905325443787,
#                           'F ratio': 0.1136094674556213,
#                           'F - M': -0.7727810650887574,
#                           'PPMI': 0}),
#              'wanting': defaultdict(None,
#                          {'M count': 2,
#                           'F count': 0,
#                           'total': 2,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'use': defaultdict(None,
#                          {'M count': 214,
#                           'F count': 36,
#                           'total': 250,
#                           'M ratio': 0.856,
#                           'F ratio': 0.144,
#                           'F - M': -0.712,
#                           'PPMI': 0.2052872161352945}),
#              'author': defaultdict(None,
#                          {'M count': 4,
#                           'F count': 0,
#                           'total': 4,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'paying': defaultdict(None,
#                          {'M count': 14,
#                           'F count': 0,
#                           'total': 14,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'money': defaultdict(None,
#                          {'M count': 132,
#                           'F count': 12,
#                           'total': 144,
#                           'M ratio': 0.9166666666666666,
#                           'F ratio': 0.08333333333333333,
#                           'F - M': -0.8333333333333333,
#                           'PPMI': 0}),
#              'signals': defaultdict(None,
#                          {'M count': 7,
#                           'F count': 0,
#                           'total': 7,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'a': defaultdict(None,
#                          {'M count': 6963,
#                           'F count': 1058,
#                           'total': 8021,
#                           'M ratio': 0.8680962473507045,
#                           'F ratio': 0.1319037526492956,
#                           'F - M': -0.7361924947014089,
#                           'PPMI': 0.07870401417858504}),
#              'plan': defaultdict(None,
#                          {'M count': 150,
#                           'F count': 10,
#                           'total': 160,
#                           'M ratio': 0.9375,
#                           'F ratio': 0.0625,
#                           'F - M': -0.875,
#                           'PPMI': 0}),
#              'convention': defaultdict(None,
#                          {'M count': 125,
#                           'F count': 0,
#                           'total': 125,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
# ...
#                           'total': 248,
#                           'M ratio': 0.8266129032258065,
#                           'F ratio': 0.17338709677419356,
#                           'F - M': -0.653225806451613,
#                           'PPMI': 0.47321494367029204}),
#              'alternative': defaultdict(None,
#                          {'M count': 36,
#                           'F count': 2,
#                           'total': 38,
#                           'M ratio': 0.9473684210526315,
#                           'F ratio': 0.05263157894736842,
#                           'F - M': -0.894736842105263,
#                           'PPMI': 0}),
#              'available': defaultdict(None,
#                          {'M count': 81,
#                           'F count': 8,
#                           'total': 89,
#                           'M ratio': 0.9101123595505618,
#                           'F ratio': 0.0898876404494382,
#                           'F - M': -0.8202247191011236,
#                           'PPMI': 0}),
#              'explicitly': defaultdict(None,
#                          {'M count': 15,
#                           'F count': 2,
#                           'total': 17,
#                           'M ratio': 0.8823529411764706,
#                           'F ratio': 0.11764705882352941,
#                           'F - M': -0.7647058823529411,
#                           'PPMI': 0}),
#              'bargained': defaultdict(None,
#                          {'M count': 2,
#                           'F count': 0,
#                           'total': 2,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'says': defaultdict(None,
#                          {'M count': 370,
#                           'F count': 56,
#                           'total': 426,
#                           'M ratio': 0.8685446009389671,
#                           'F ratio': 0.13145539906103287,
#                           'F - M': -0.7370892018779343,
#                           'PPMI': 0.07379180118683536}),
#              'non': defaultdict(None,
#                          {'M count': 137,
#                           'F count': 6,
#                           'total': 143,
#                           'M ratio': 0.958041958041958,
#                           'F ratio': 0.04195804195804196,
#                           'F - M': -0.916083916083916,
#                           'PPMI': 0}),
#              'commercial': defaultdict(None,
#                          {'M count': 22,
#                           'F count': 4,
#                           'total': 26,
#                           'M ratio': 0.8461538461538461,
#                           'F ratio': 0.15384615384615385,
#                           'F - M': -0.6923076923076923,
#                           'PPMI': 0.30070678121397704}),
#              'purposes': defaultdict(None,
#                          {'M count': 96,
#                           'F count': 10,
#                           'total': 106,
#                           'M ratio': 0.9056603773584906,
#                           'F ratio': 0.09433962264150944,
#                           'F - M': -0.8113207547169812,
#                           'PPMI': 0}),
#              'highlights': defaultdict(None,
#                          {'M count': 5,
#                           'F count': 0,
#                           'total': 5,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'scope': defaultdict(None,
#                          {'M count': 40,
#                           'F count': 7,
#                           'total': 47,
#                           'M ratio': 0.851063829787234,
#                           'F ratio': 0.14893617021276595,
#                           'F - M': -0.7021276595744681,
#                           'PPMI': 0.253912569735036}),
#              'contractual': defaultdict(None,
#                          {'M count': 6,
#                           'F count': 2,
#                           'total': 8,
#                           'M ratio': 0.75,
#                           'F ratio': 0.25,
#                           'F - M': -0.5,
#                           'PPMI': 1.0011464993550694}),
#              'license': defaultdict(None,
#                          {'M count': 46,
#                           'F count': 13,
#                           'total': 59,
#                           'M ratio': 0.7796610169491526,
#                           'F ratio': 0.22033898305084745,
#                           'F - M': -0.5593220338983051,
#                           'PPMI': 0.81894316813432}),
#              'pending': defaultdict(None,
#                          {'M count': 19,
#                           'F count': 1,
#                           'total': 20,
#                           'M ratio': 0.95,
#                           'F ratio': 0.05,
#                           'F - M': -0.8999999999999999,
#                           'PPMI': 0}),
#              'breach': defaultdict(None,
#                          {'M count': 41,
#                           'F count': 0,
#                           'total': 41,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'contract': defaultdict(None,
#                          {'M count': 159,
#                           'F count': 13,
#                           'total': 172,
#                           'M ratio': 0.9244186046511628,
#                           'F ratio': 0.0755813953488372,
#                           'F - M': -0.8488372093023255,
#                           'PPMI': 0}),
#              'partner': defaultdict(None,
#                          {'M count': 2,
#                           'F count': 2,
#                           'total': 4,
#                           'M ratio': 0.5,
#                           'F ratio': 0.5,
#                           'F - M': 0.0,
#                           'PPMI': 2.0011464993550696}),
#              'intersal': defaultdict(None,
#                          {'M count': 4,
#                           'F count': 0,
#                           'total': 4,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'debating': defaultdict(None,
#                          {'M count': 2,
#                           'F count': 1,
#                           'total': 3,
#                           'M ratio': 0.6666666666666666,
#                           'F ratio': 0.3333333333333333,
#                           'F - M': -0.3333333333333333,
#                           'PPMI': 1.416183998633913}),
#              'exceeded': defaultdict(None,
#                          {'M count': 2,
#                           'F count': 0,
#                           'total': 2,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'example': defaultdict(None,
#                          {'M count': 229,
#                           'F count': 38,
#                           'total': 267,
#                           'M ratio': 0.8576779026217228,
#                           'F ratio': 0.14232209737827714,
#                           'F - M': -0.7153558052434457,
#                           'PPMI': 0.18837808111110074}),
#              'putting': defaultdict(None,
#                          {'M count': 29,
#                           'F count': 5,
#                           'total': 34,
#                           'M ratio': 0.8529411764705882,
#                           'F ratio': 0.14705882352941177,
#                           'F - M': -0.7058823529411764,
#                           'PPMI': 0.23561175299209203}),
#              'asserted': defaultdict(None,
#                          {'M count': 15,
#                           'F count': 0,
#                           'total': 15,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'affirmatively': defaultdict(None,
#                          {'M count': 11,
#                           'F count': 2,
#                           'total': 13,
#                           'M ratio': 0.8461538461538461,
#                           'F ratio': 0.15384615384615385,
#                           'F - M': -0.6923076923076923,
#                           'PPMI': 0.30070678121397704}),
#              'waived': defaultdict(None,
#                          {'M count': 12,
#                           'F count': 6,
#                           'total': 18,
#                           'M ratio': 0.6666666666666666,
#                           'F ratio': 0.3333333333333333,
#                           'F - M': -0.3333333333333333,
#                           'PPMI': 1.4161839986339129}),
#              'strange': defaultdict(None,
#                          {'M count': 9,
#                           'F count': 0,
#                           'total': 9,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'ca': defaultdict(None,
#                          {'M count': 210,
#                           'F count': 47,
#                           'total': 257,
#                           'M ratio': 0.8171206225680934,
#                           'F ratio': 0.1828793774319066,
#                           'F - M': -0.6342412451361867,
#                           'PPMI': 0.5501108018388285}),
#              'possibly': defaultdict(None,
#                          {'M count': 19,
#                           'F count': 1,
#                           'total': 20,
#                           'M ratio': 0.95,
#                           'F ratio': 0.05,
#                           'F - M': -0.8999999999999999,
#                           'PPMI': 0}),
#              'relevance': defaultdict(None,
#                          {'M count': 5,
#                           'F count': 0,
#                           'total': 5,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'alleged': defaultdict(None,
#                          {'M count': 35,
#                           'F count': 3,
#                           'total': 38,
#                           'M ratio': 0.9210526315789473,
#                           'F ratio': 0.07894736842105263,
#                           'F - M': -0.8421052631578947,
#                           'PPMI': 0}),
#              'exposes': defaultdict(None,
#                          {'M count': 4,
#                           'F count': 0,
#                           'total': 4,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'second': defaultdict(None,
#                          {'M count': 298,
#                           'F count': 47,
#                           'total': 345,
#                           'M ratio': 0.863768115942029,
#                           'F ratio': 0.13623188405797101,
#                           'F - M': -0.7275362318840579,
#                           'PPMI': 0.12528279936717493}),
#              'types': defaultdict(None,
#                          {'M count': 30,
#                           'F count': 14,
#                           'total': 44,
#                           'M ratio': 0.6818181818181818,
#                           'F ratio': 0.3181818181818182,
#                           'F - M': -0.3636363636363636,
#                           'PPMI': 1.349069802775376}),
#              'related': defaultdict(None,
#                          {'M count': 44,
#                           'F count': 2,
#                           'total': 46,
#                           'M ratio': 0.9565217391304348,
#                           'F ratio': 0.043478260869565216,
#                           'F - M': -0.9130434782608696,
#                           'PPMI': 0}),
#              'declaratory': defaultdict(None,
#                          {'M count': 10,
#                           'F count': 0,
#                           'total': 10,
#                           'M ratio': 1.0,
#                           'F ratio': 0.0,
#                           'F - M': -1.0,
#                           'PPMI': 0}),
#              'declared': defaultdict(None,
#                          {'M count': 3,
#                           'F count': 1,
#                           'total': 4,
#                           'M ratio': 0.75,
#                           'F ratio': 0.25,
#                           'F - M': -0.5,
#                           'PPMI': 1.0011464993550694}),
#              'preempted': defaultdict(None,
#                          {'M count': 11,
#                           'F count': 1,
#                           'total': 12,
#                           'M ratio': 0.9166666666666666,
#                           'F ratio': 0.08333333333333333,
#                           'F - M': -0.8333333333333333,
#                           'PPMI': 0}),
#              'sought': defaultdict(None,
#                          {'M count': 30,
#                           'F count': 3,
#                           'total': 33,
#                           'M ratio': 0.9090909090909091,
#                           'F ratio': 0.09090909090909091,
#                           'F - M': -0.8181818181818181,
#                           'PPMI': 0}),
#              'cert': defaultdict(None,
#                          {'M count': 27,
#                           'F count': 6,
#                           'total': 33,
#                           'M ratio': 0.8181818181818182,
#                           'F ratio': 0.18181818181818182,
#                           'F - M': -0.6363636363636365,
#                           'PPMI': 0.5417148807177721}),
#              'circumstance': defaultdict(None,
#                          {'M count': 64,
#                           'F count': 9,
#                           'total': 73,
#                           'M ratio': 0.8767123287671232,
#                           'F ratio': 0.1232876712328767,
#                           'F - M': -0.7534246575342465,
#                           'PPMI': 0}),
#              'district': defaultdict(None,
#                          {'M count': 243,
#                           'F count': 74,
#                           'total': 317,
#                           'M ratio': 0.7665615141955836,
#                           'F ratio': 0.2334384858044164,
#                           'F - M': -0.5331230283911672,
#                           'PPMI': 0.9022608348446118}),
#              'fourth': defaultdict(None,
#                          {'M count': 47,
#                           'F count': 11,
#                           'total': 58,
#                           'M ratio': 0.8103448275862069,
#                           'F ratio': 0.1896551724137931,
#                           'F - M': -0.6206896551724137,
#                           'PPMI': 0.6025971228647943}),
#              'pages': defaultdict(None,
#                          {'M count': 45,
#                           'F count': 8,
#                           'total': 53,
#                           'M ratio': 0.8490566037735849,
#                           'F ratio': 0.1509433962264151,
#                           'F - M': -0.6981132075471699,
#                           'PPMI': 0.2732260447918698}),
#              'appendix': defaultdict(None,
#                          {'M count': 48,
#                           'F count': 15,
#                           'total': 63,
#                           'M ratio': 0.7619047619047619,
#                           'F ratio': 0.23809523809523808,
#                           'F - M': -0.5238095238095237,
#                           'PPMI': 0.9307571714636714}),
#              ...})
