# %%
from typing import Dict, Iterable, List, Tuple
from convokit import Corpus, Speaker, Utterance, download
from collections import defaultdict, Counter

# %%
corpus = Corpus(filename="supreme_processed")

# Filter out speakers without gender signal
corpus = corpus.filter_utterances_by(
    lambda utt: utt.get_speaker().retrieve_meta("gender_signal") != None
)

# %%
# Our goal is to build a table with each word token in the vocabulary for the Supreme Court corpus, 
# listing the number of male and female speakers as well as some percentages.
table = defaultdict(Counter)
# keys: tokens in the vocabulary
        # values: Counter dictionaries 
            #keys: gender signals
            #values: how many speakers of given gender have said the token

"""Flattens the "tokens" dictionary of an Utterance into a list."""
def get_tokens(utt: Utterance) -> List[str]:
    return [tok["tok"]
            for sent in utt.retrieve_meta("tokens")
            for tok in sent["toks"]]

for utt in corpus.iter_utterances():
    tokens = get_tokens(utt)
    gender = utt.get_speaker().retrieve_meta("gender_signal")
    for token in tokens:
        table[token][gender] += 1

table
# Out:
# defaultdict(collections.Counter,
#             {'mr': Counter({'M': 353, 'F': 52}),
#              '.': Counter({'M': 14717, 'F': 2273}),
#              'chief': Counter({'M': 245, 'F': 40}),
#              'justice': Counter({'M': 962, 'F': 149}),
#              ',': Counter({'M': 19757, 'F': 2859}),
#              'and': Counter({'M': 8012, 'F': 1228}),
#              'may': Counter({'M': 363, 'F': 58}),
#              'it': Counter({'M': 5769, 'F': 906}),
#              'please': Counter({'M': 133, 'F': 21}),
#              'the': Counter({'M': 22049, 'F': 2563}),
#              'court': Counter({'M': 2401, 'F': 349}),
#              ':': Counter({'M': 268, 'F': 42}),
#              'when': Counter({'M': 673, 'F': 96}),
#              'states': Counter({'M': 371, 'F': 32}),
#              'infringe': Counter({'M': 9, 'F': 1}),
#              'exclusive': Counter({'M': 19}),
#              'federal': Counter({'M': 418, 'F': 29}),
#              'rights': Counter({'M': 147, 'F': 9}),
#              'that': Counter({'M': 12310, 'F': 1745}),
#              'congress': Counter({'M': 1010, 'F': 31}),
#              'is': Counter({'M': 5953, 'F': 891}),
#              'charged': Counter({'M': 17, 'F': 1}),
#              'with': Counter({'M': 1518, 'F': 177}),
#              'securing': Counter({'M': 3, 'F': 1}),
#              'can': Counter({'M': 777, 'F': 128}),
#              'make': Counter({'M': 415, 'F': 49}),
#              'pay': Counter({'M': 127, 'F': 6}),
#              'for': Counter({'M': 2306, 'F': 282}),
#              'doing': Counter({'M': 151, 'F': 10}),
#              'so': Counter({'M': 1837, 'F': 401}),
#              "'s": Counter({'M': 5225, 'F': 802}),
#              'our': Counter({'M': 586, 'F': 78}),
#              'respectful': Counter({'M': 5}),
#              'submission': Counter({'M': 25}),
#              'today': Counter({'M': 80, 'F': 19}),
#              'one': Counter({'M': 836, 'F': 130}),
#              'follows': Counter({'M': 14, 'F': 2}),
#              'from': Counter({'M': 891, 'F': 101}),
#              'constitution': Counter({'M': 107, 'F': 2}),
#              'text': Counter({'M': 183, 'F': 5}),
#              'affords': Counter({'M': 3}),
#              'ample': Counter({'M': 6}),
#              'basis': Counter({'M': 136, 'F': 14}),
#              'this': Counter({'M': 3116, 'F': 454}),
#              'to': Counter({'M': 9580, 'F': 1249}),
#              'uphold': Counter({'M': 9}),
#              'work': Counter({'M': 131, 'F': 8}),
#              'did': Counter({'M': 671, 'F': 87}),
#              'in': Counter({'M': 6194, 'F': 800}),
#              'enacting': Counter({'M': 11}),
#              'crca': Counter({'M': 13}),
#              'article': Counter({'M': 150}),
#              'i': Counter({'M': 5570, 'F': 700}),
#              'section': Counter({'M': 295, 'F': 43}),
#              '<': Counter({'M': 1864, 'F': 258}),
#              'number': Counter({'M': 1504, 'F': 220}),
#              '>': Counter({'M': 1586, 'F': 229}),
#              'clause': Counter({'M': 181, 'F': 11}),
#              'what': Counter({'M': 1576, 'F': 221}),
#              'we': Counter({'M': 2476, 'F': 349}),
#              "'re": Counter({'M': 969, 'F': 137}),
#              'calling': Counter({'M': 11, 'F': 2}),
#              'intellectual': Counter({'M': 6}),
#              'property': Counter({'M': 172, 'F': 5}),
#              'unique': Counter({'M': 20, 'F': 5}),
#              'within': Counter({'M': 157, 'F': 6}),
#              'laying': Counter({'M': 3}),
#              'down': Counter({'M': 94, 'F': 11}),
#              'an': Counter({'M': 1356, 'F': 180}),
#              'express': Counter({'M': 32, 'F': 2}),
#              'constitutional': Counter({'M': 170, 'F': 14}),
#              'mandate': Counter({'M': 28, 'F': 1}),
#              'protect': Counter({'M': 45, 'F': 9}),
#              'specified': Counter({'M': 16}),
#              'private': Counter({'M': 109, 'F': 2}),
#              'against': Counter({'M': 185, 'F': 36}),
#              'any': Counter({'M': 630, 'F': 80}),
#              'all': Counter({'M': 974, 'F': 117}),
#              'intrusion': Counter({'M': 6}),
#              'consider': Counter({'M': 59, 'F': 21}),
#              'just': Counter({'M': 840, 'F': 195}),
#              'how': Counter({'M': 328, 'F': 55}),
#              'pointed': Counter({'M': 62, 'F': 9}),
#              'clear': Counter({'M': 338, 'F': 59}),
#              'not': Counter({'M': 2873, 'F': 428}),
#              'only': Counter({'M': 435, 'F': 70}),
#              'be': Counter({'M': 2385, 'F': 285}),
#              'granting': Counter({'M': 15, 'F': 1}),
#              'copyrights': Counter({'M': 19}),
#              'but': Counter({'M': 1968, 'F': 309}),
#              'them': Counter({'M': 345, 'F': 48}),
#              'resulting': Counter({'M': 4, 'F': 1}),
#              'by': Counter({'M': 953, 'F': 99}),
#              'definition': Counter({'M': 59, 'F': 5}),
#              'are': Counter({'M': 1755, 'F': 269}),
#              'meant': Counter({'M': 43, 'F': 3}),
#              'whom': Counter({'M': 13, 'F': 3}),
#              'your': Counter({'M': 952, 'F': 120}),
#              'honors': Counter({'M': 18, 'F': 1}),
#              '?': Counter({'M': 327, 'F': 53}),
#              'comers': Counter({'M': 1}),
#              'world': Counter({'M': 33, 'F': 12}),
#              'including': Counter({'M': 89, 'F': 17}),
#              'government': Counter({'M': 605, 'F': 32}),
#              'exercise': Counter({'M': 87, 'F': 2}),
#              'of': Counter({'M': 8056, 'F': 1077}),
#              'congressional': Counter({'M': 39, 'F': 4}),
#              'power': Counter({'M': 199, 'F': 5}),
#              'serves': Counter({'M': 5, 'F': 2}),
#              'purpose': Counter({'M': 83, 'F': 1}),
#              'promote': Counter({'M': 6}),
#              'progress': Counter({'M': 6}),
#              'affording': Counter({'M': 3}),
#              'monetary': Counter({'M': 9, 'F': 6}),
#              'recompense': Counter({'M': 1}),
#              'copyright': Counter({'M': 108, 'F': 1}),
#              'holders': Counter({'M': 17}),
#              'framers': Counter({'M': 26}),
#              'thus': Counter({'M': 13, 'F': 5}),
#              'made': Counter({'M': 275, 'F': 28}),
#              'very': Counter({'M': 466, 'F': 70}),
#              'those': Counter({'M': 749, 'F': 96}),
#              'wanting': Counter({'M': 2}),
#              'use': Counter({'M': 214, 'F': 36}),
#              'author': Counter({'M': 4}),
#              'paying': Counter({'M': 14}),
#              'money': Counter({'M': 132, 'F': 12}),
#              'signals': Counter({'M': 7}),
#              'a': Counter({'M': 6963, 'F': 1058}),
#              'plan': Counter({'M': 150, 'F': 10}),
#              'convention': Counter({'M': 125}),
#              'waiver': Counter({'M': 12, 'F': 3}),
#              'like': Counter({'M': 568, 'F': 102}),
#              'no': Counter({'M': 1141, 'F': 196}),
#              'other': Counter({'M': 662, 'F': 124}),
#              'i.': Counter({'M': 5, 'F': 1}),
#              'retain': Counter({'M': 9, 'F': 1}),
#              'immunity': Counter({'M': 73, 'F': 3}),
#              'avoid': Counter({'M': 25, 'F': 5}),
#              'infringing': Counter({'M': 9, 'F': 3}),
#              'same': Counter({'M': 419, 'F': 74}),
#              'secure': Counter({'M': 4}),
#              'would': Counter({'M': 2112, 'F': 271}),
#              'incompatible': Counter({'M': 2}),
#              'as': Counter({'M': 1972, 'F': 191}),
#              'fixed': Counter({'M': 9}),
#              'understood': Counter({'M': 78, 'F': 6}),
#              'has': Counter({'M': 1350, 'F': 201}),
#              'already': Counter({'M': 95, 'F': 27}),
#              'recognized': Counter({'M': 101, 'F': 17}),
#              'substance': Counter({'M': 41, 'F': 3}),
#              'going': Counter({'M': 540, 'F': 89}),
#              'back': Counter({'M': 214, 'F': 29}),
#              'united': Counter({'M': 165, 'F': 13}),
#              'v.': Counter({'M': 33, 'F': 6}),
#              'palmer': Counter({'M': 1}),
#              'said': Counter({'M': 689, 'F': 92}),
#              'holding': Counter({'M': 46, 'F': 8}),
#              'monetarily': Counter({'M': 1}),
#              'liable': Counter({'M': 21, 'F': 10}),
#              'patents': Counter({'M': 8}),
#              'were': Counter({'M': 735, 'F': 87}),
#              'talking': Counter({'M': 138, 'F': 25}),
#              'about': Counter({'M': 913, 'F': 147}),
#              'could': Counter({'M': 686, 'F': 110}),
#              'affected': Counter({'M': 12}),
#              'if': Counter({'M': 1845, 'F': 260}),
#              'had': Counter({'M': 566, 'F': 86}),
#              'reserve': Counter({'M': 15, 'F': 1}),
#              'right': Counter({'M': 548, 'F': 88}),
#              'reasoning': Counter({'M': 33, 'F': 8}),
#              'holds': Counter({'M': 16, 'F': 1}),
#              'goldstein': Counter({'M': 3}),
#              'california': Counter({'M': 4}),
#              '--': Counter({'M': 9849, 'F': 1263}),
#              'again': Counter({'M': 257, 'F': 88}),
#              'here': Counter({'M': 948, 'F': 128}),
#              'discussing': Counter({'M': 19, 'F': 3}),
#              'grants': Counter({'M': 10}),
#              'or': Counter({'M': 1350, 'F': 193}),
#              'monopoly': Counter({'M': 3, 'F': 2}),
#              'its': Counter({'M': 431, 'F': 50}),
#              'effects': Counter({'M': 7, 'F': 1}),
#              'pervasive': Counter({'M': 1}),
#              'citizen': Counter({'M': 15, 'F': 2}),
#              'state': Counter({'M': 709, 'F': 84}),
#              'escape': Counter({'M': 3}),
#              'reach': Counter({'M': 34, 'F': 2}),
#              'correct': Counter({'M': 162, 'F': 42}),
#              'ginsburg': Counter({'M': 88, 'F': 13}),
#              'was': Counter({'M': 2144, 'F': 325}),
#              'examining': Counter({'M': 7}),
#              'fact': Counter({'M': 366, 'F': 62}),
#              "n't": Counter({'M': 2296, 'F': 390}),
#              'even': Counter({'M': 553, 'F': 83}),
#              'grant': Counter({'M': 50, 'F': 2}),
#              'review': Counter({'M': 288, 'F': 9}),
#              'on': Counter({'M': 1764, 'F': 305}),
#              'question': Counter({'M': 730, 'F': 76}),
#              'whether': Counter({'M': 526, 'F': 83}),
#              'patent': Counter({'M': 76, 'F': 1}),
#              'remedy': Counter({'M': 140, 'F': 26}),
#              'act': Counter({'M': 345, 'F': 62}),
#              'valid': Counter({'M': 35, 'F': 8}),
#              'before': Counter({'M': 227, 'F': 36}),
#              'raised': Counter({'M': 47, 'F': 9}),
#              'refer': Counter({'M': 35, 'F': 4}),
#              'seminole': Counter({'M': 12}),
#              'tribe': Counter({'M': 41}),
#              'sweeping': Counter({'M': 4}),
#              'assumption': Counter({'M': 18, 'F': 4}),
#              'ever': Counter({'M': 74, 'F': 8}),
#              'supply': Counter({'M': 5}),
#              'abrogation': Counter({'M': 5}),
#              'katz': Counter({'M': 13}),
#              'more': Counter({'M': 364, 'F': 52}),
#              'recently': Counter({'M': 22, 'F': 1}),
#              'called': Counter({'M': 47, 'F': 8}),
#              'dicta': Counter({'M': 6}),
#              'held': Counter({'M': 85, 'F': 20}),
#              'erroneous': Counter({'M': 11}),
#              'which': Counter({'M': 1074, 'F': 116}),
#              'way': Counter({'M': 492, 'F': 68}),
#              'able': Counter({'M': 98, 'F': 20}),
#              'analyze': Counter({'M': 5}),
#              'specifics': Counter({'M': 5}),
#              'bankruptcy': Counter({'M': 101, 'F': 2}),
#              'find': Counter({'M': 62, 'F': 8}),
#              'reflect': Counter({'M': 9, 'F': 1}),
#              'honor': Counter({'M': 710, 'F': 80}),
#              'rely': Counter({'M': 37, 'F': 11}),
#              'upon': Counter({'M': 63, 'F': 2}),
#              'methodology': Counter({'M': 1, 'F': 5}),
#              'upfront': Counter({'M': 3, 'F': 1}),
#              'take': Counter({'M': 204, 'F': 43}),
#              'supplying': Counter({'M': 1}),
#              'relevant': Counter({'M': 110, 'F': 19}),
#              'portion': Counter({'M': 15, 'F': 1}),
#              'both': Counter({'M': 185, 'F': 21}),
#              'majority': Counter({'M': 31, 'F': 12}),
#              'dissent': Counter({'M': 13, 'F': 4}),
#              'case': Counter({'M': 1340, 'F': 210}),
#              'dealt': Counter({'M': 26, 'F': 2}),
#              'commerce': Counter({'M': 13}),
#              'breath': Counter({'M': 6, 'F': 1}),
#              'sentences': Counter({'M': 34, 'F': 4}),
#              'kagan': Counter({'M': 105, 'F': 18}),
#              'exact': Counter({'M': 42, 'F': 3}),
#              'clauses': Counter({'M': 13, 'F': 2}),
#              'stevens': Counter({'M': 5}),
#              "'": Counter({'M': 169, 'F': 22}),
#              'think': Counter({'M': 2865, 'F': 392}),
#              'first': Counter({'M': 549, 'F': 85}),
#              'footnote': Counter({'M': 39, 'F': 5}),
#              'he': Counter({'M': 395, 'F': 96}),
#              'noted': Counter({'M': 29, 'F': 3}),
#              'decision': Counter({'M': 432, 'F': 31}),
#              'terms': Counter({'M': 153, 'F': 52}),
#              'apply': Counter({'M': 243, 'F': 26}),
#              'rehnquist': Counter({'M': 3}),
#              'engaged': Counter({'M': 19}),
#              'yes': Counter({'M': 401, 'F': 82}),
#              'essentially': Counter({'M': 71, 'F': 8}),
#              'big': Counter({'M': 29, 'F': 1}),
#              'deal': Counter({'M': 41, 'F': 4}),
#              'necessary': Counter({'M': 57, 'F': 11}),
#              'upshot': Counter({'M': 2}),
#              'articulated': Counter({'M': 17, 'F': 3}),
#              'why': Counter({'M': 261, 'F': 59}),
#              'rejected': Counter({'M': 56, 'F': 10}),
#              'let': Counter({'M': 178, 'F': 47}),
#              'me': Counter({'M': 228, 'F': 53}),
#              'assure': Counter({'M': 8, 'F': 1}),
#              'there': Counter({'M': 2224, 'F': 276}),
#              'contemplates': Counter({'M': 8}),
#              'will': Counter({'M': 363, 'F': 43}),
#              'certainly': Counter({'M': 163, 'F': 19}),
#              'open': Counter({'M': 39, 'F': 5}),
#              'folks': Counter({'M': 1}),
#              'cases': Counter({'M': 596, 'F': 98}),
#              'argument': Counter({'M': 279, 'F': 37}),
#              'my': Counter({'M': 389, 'F': 39}),
#              'prediction': Counter({'M': 8}),
#              'ultimately': Counter({'M': 65, 'F': 2}),
#              'revisited': Counter({'M': 2}),
#              'properly': Counter({'M': 32, 'F': 1}),
#              'upheld': Counter({'M': 12, 'F': 1}),
#              "'m": Counter({'M': 345, 'F': 50}),
#              'asking': Counter({'M': 87, 'F': 23}),
#              'follow': Counter({'M': 31, 'F': 7}),
#              'alito': Counter({'M': 105, 'F': 19}),
#              'where': Counter({'M': 609, 'F': 92}),
#              'florida': Counter({'M': 58}),
#              'prepaid': Counter({'M': 14}),
#              'overruled': Counter({'M': 6, 'F': 2}),
#              'part': Counter({'M': 246, 'F': 23}),
#              'precedential': Counter({'M': 2}),
#              'foundation': Counter({'M': 3, 'F': 1}),
#              'solely': Counter({'M': 13}),
#              'exactly': Counter({'M': 177, 'F': 24}),
#              'have': Counter({'M': 2037, 'F': 316}),
#              'totally': Counter({'M': 8, 'F': 2}),
#              'undermined': Counter({'M': 5}),
#              'friendly': Counter({'M': 2, 'F': 4}),
#              'amendment': Counter({'M': 215, 'F': 18}),
#              'do': Counter({'M': 1771, 'F': 267}),
#              'reflects': Counter({'M': 7, 'F': 3}),
#              'sense': Counter({'M': 136, 'F': 21}),
#              'implications': Counter({'M': 10}),
#              'because': Counter({'M': 1225, 'F': 215}),
#              'reasons': Counter({'M': 167, 'F': 25}),
#              'contemplation': Counter({'M': 2, 'F': 1}),
#              'say': Counter({'M': 690, 'F': 98}),
#              'such': Counter({'M': 152, 'F': 18}),
#              'thing': Counter({'M': 224, 'F': 27}),
#              'secured': Counter({'M': 6}),
#              'free': Counter({'M': 76, 'F': 8}),
#              'without': Counter({'M': 158, 'F': 33}),
#              'been': Counter({'M': 519, 'F': 77}),
#              'antithetical': Counter({'M': 2}),
#              'conception': Counter({'M': 3}),
#              'does': Counter({'M': 743, 'F': 97}),
#              'questions': Counter({'M': 158, 'F': 18}),
#              "'ll": Counter({'M': 111, 'F': 12}),
#              'move': Counter({'M': 28, 'F': 1}),
#              'well': Counter({'M': 883, 'F': 89}),
#              'kavanaugh': Counter({'M': 79, 'F': 10}),
#              'obviously': Counter({'M': 72, 'F': 13}),
#              'decide': Counter({'M': 93, 'F': 23}),
#              'precedent': Counter({'M': 36, 'F': 6}),
#              'read': Counter({'M': 133, 'F': 22}),
#              'having': Counter({'M': 77, 'F': 10}),
#              'really': Counter({'M': 262, 'F': 50}),
#              'squarely': Counter({'M': 13, 'F': 5}),
#              'addressed': Counter({'M': 43, 'F': 3}),
#              'reached': Counter({'M': 15, 'F': 1}),
#              'point': Counter({'M': 523, 'F': 60}),
#              'presented': Counter({'M': 66, 'F': 9}),
#              'party': Counter({'M': 149, 'F': 29}),
#              'arguing': Counter({'M': 31, 'F': 5}),
#              'respectfully': Counter({'M': 25, 'F': 1}),
#              'truly': Counter({'M': 12, 'F': 1}),
#              'based': Counter({'M': 200, 'F': 37}),
#              'aspect': Counter({'M': 13, 'F': 3}),
#              'revisiting': Counter({'M': 5}),
#              'overruling': Counter({'M': 2, 'F': 1}),
#              'status': Counter({'M': 114, 'F': 7}),
#              'qualms': Counter({'M': 1}),
#              'ask': Counter({'M': 75, 'F': 16}),
#              'sustain': Counter({'M': 9}),
#              'strength': Counter({'M': 3}),
#              'fourteenth': Counter({'M': 15, 'F': 1}),
#              'turn': Counter({'M': 57, 'F': 11}),
#              'sotomayor': Counter({'M': 85, 'F': 15}),
#              'refers': Counter({'M': 29, 'F': 2}),
#              'some': Counter({'M': 409, 'F': 71}),
#              'reflection': Counter({'M': 1, 'F': 1}),
#              'surrendering': Counter({'M': 1}),
#              'their': Counter({'M': 582, 'F': 79}),
#              '-': Counter({'M': 1230, 'F': 205}),
#              'dropped': Counter({'M': 3, 'F': 1}),
#              'default': Counter({'M': 18}),
#              'sovereign': Counter({'M': 35, 'F': 5}),
#              'discrete': Counter({'M': 17}),
#              'respect': Counter({'M': 252, 'F': 10}),
#              'came': Counter({'M': 52, 'F': 8}),
#              'out': Counter({'M': 436, 'F': 86}),
#              'textual': Counter({'M': 26, 'F': 4}),
#              'stronger': Counter({'M': 10}),
#              'than': Counter({'M': 290, 'F': 59}),
#              'you': Counter({'M': 2965, 'F': 559}),
#              'habeas': Counter({'M': 121}),
#              'jurisdiction': Counter({'M': 106, 'F': 3}),
#              'relief': Counter({'M': 182, 'F': 19}),
#              'hauling': Counter({'M': 1}),
#              'into': Counter({'M': 267, 'F': 26}),
#              'get': Counter({'M': 298, 'F': 95}),
#              'prisoners': Counter({'M': 8}),
#              'prison': Counter({'M': 12, 'F': 2}),
#              'anywhere': Counter({'M': 12, 'F': 2}),
#              'near': Counter({'M': 6, 'F': 3}),
#              'clearly': Counter({'M': 121, 'F': 15}),
#              'these': Counter({'M': 473, 'F': 85}),
#              'anyone': Counter({'M': 26, 'F': 3}),
#              'who': Counter({'M': 418, 'F': 124}),
#              'job': Counter({'M': 33, 'F': 14}),
#              'abrogating': Counter({'M': 1}),
#              'sovereignty': Counter({'M': 19}),
#              'realm': Counter({'M': 7, 'F': 1}),
#              'preamble': Counter({'M': 2}),
#              'echoed': Counter({'M': 2}),
#              'else': Counter({'M': 55, 'F': 11}),
#              'james': Counter({'M': 9}),
#              'madison': Counter({'M': 9}),
#              'reflected': Counter({'M': 7}),
#              'achieve': Counter({'M': 10, 'F': 1}),
#              'authors': Counter({'M': 4}),
#              'inventors': Counter({'M': 1}),
#              'paid': Counter({'M': 41}),
#              'inventions': Counter({'M': 1}),
#              'they': Counter({'M': 2103, 'F': 321}),
#              'creations': Counter({'M': 1}),
#              'indicated': Counter({'M': 20}),
#              'kind': Counter({'M': 200, 'F': 13}),
#              'legislative': Counter({'M': 82}),
#              'record': Counter({'M': 63, 'F': 13}),
#              'different': Counter({'M': 387, 'F': 50}),
#              'much': Counter({'M': 177, 'F': 16}),
#              'fundamental': Counter({'M': 43, 'F': 9}),
#              'difference': Counter({'M': 108, 'F': 14}),
#              'between': Counter({'M': 207, 'F': 25}),
#              'law': Counter({'M': 812, 'F': 165}),
#              'at': Counter({'M': 1389, 'F': 174}),
#              'issue': Counter({'M': 260, 'F': 40}),
#              'looking': Counter({'M': 86, 'F': 16}),
#              'also': Counter({'M': 303, 'F': 64}),
#              'register': Counter({'M': 5, 'F': 7}),
#              'ralph': Counter({'M': 2}),
#              'oman': Counter({'M': 2}),
#              'testifying': Counter({'M': 3}),
#              'preparing': Counter({'M': 4}),
#              'report': Counter({'M': 20}),
#              'number>-state': Counter({'M': 2}),
#              'survey': Counter({'M': 4, 'F': 32}),
#              'conscientious': Counter({'M': 3}),
#              'compilation': Counter({'M': 3}),
#              'comments': Counter({'M': 11}),
#              'studies': Counter({'M': 2, 'F': 1}),
#              'happening': Counter({'M': 13}),
#              'legislation': Counter({'M': 36}),
#              'serious': Counter({'M': 37}),
#              'problem': Counter({'M': 183, 'F': 23}),
#              'granted': Counter({'M': 41, 'F': 1}),
#              'conscientiously': Counter({'M': 1}),
#              'tailored': Counter({'M': 7}),
#              'around': Counter({'M': 31, 'F': 6}),
#              'should': Counter({'M': 480, 'F': 91}),
#              'put': Counter({'M': 140, 'F': 24}),
#              'city': Counter({'M': 77, 'F': 6}),
#              'boerne': Counter({'M': 8}),
#              'context': Counter({'M': 248, 'F': 36}),
#              'nature': Counter({'M': 69, 'F': 6}),
#              'respected': Counter({'M': 4}),
#              'compensated': Counter({'M': 2}),
#              'particular': Counter({'M': 218, 'F': 42}),
#              'infringement': Counter({'M': 53, 'F': 14}),
#              'means': Counter({'M': 122, 'F': 27}),
#              'someone': Counter({'M': 103, 'F': 35}),
#              'copied': Counter({'M': 6}),
#              'protected': Counter({'M': 34, 'F': 4}),
#              'original': Counter({'M': 36, 'F': 3}),
#              'expression': Counter({'M': 4}),
#              'holder': Counter({'M': 7}),
#              'violation': Counter({'M': 106, 'F': 11}),
#              'pretty': Counter({'M': 31, 'F': 6}),
#              'every': Counter({'M': 197, 'F': 36}),
#              'time': Counter({'M': 362, 'F': 33}),
#              'negligent': Counter({'M': 5, 'F': 3}),
#              'permit': Counter({'M': 38, 'F': 2}),
#              'procedural': Counter({'M': 40, 'F': 3}),
#              'due': Counter({'M': 59, 'F': 10}),
#              'process': Counter({'M': 190, 'F': 7}),
#              'violations': Counter({'M': 26, 'F': 2}),
#              'sorts': Counter({'M': 16, 'F': 2}),
#              'things': Counter({'M': 205, 'F': 34}),
#              'negligently': Counter({'M': 1}),
#              'denying': Counter({'M': 18, 'F': 3}),
#              'notice': Counter({'M': 36, 'F': 15}),
#              'opportunity': Counter({'M': 62, 'F': 16}),
#              'heard': Counter({'M': 22, 'F': 4}),
#              'spurious': Counter({'M': 2}),
#              'welfare': Counter({'M': 1}),
#              'cancellation': Counter({'M': 18, 'F': 7}),
#              'offend': Counter({'M': 2}),
#              'takings': Counter({'M': 7, 'F': 1}),
#              'taking': Counter({'M': 50, 'F': 7}),
#              'occur': Counter({'M': 16, 'F': 2}),
#              'through': Counter({'M': 183, 'F': 18}),
#              'regulatory': Counter({'M': 49}),
#              'penn': Counter({'M': 2}),
#              'central': Counter({'M': 19, 'F': 2}),
#              'predictable': Counter({'M': 1, 'F': 1}),
#              'result': Counter({'M': 99, 'F': 11}),
#              'action': Counter({'M': 227, 'F': 39}),
#              'denies': Counter({'M': 3, 'F': 3}),
#              'compensation': Counter({'M': 5, 'F': 3}),
#              'submit': Counter({'M': 38}),
#              'true': Counter({'M': 149, 'F': 38}),
#              'most': Counter({'M': 152, 'F': 16}),
#              'prophylactic': Counter({'M': 4}),
#              'deterrent': Counter({'M': 9}),
#              'under': Counter({'M': 807, 'F': 88}),
#              'note': Counter({'M': 38, 'F': 4}),
#              'examples': Counter({'M': 40, 'F': 18}),
#              'reports': Counter({'M': 15}),
#              'motion': Counter({'M': 127, 'F': 3}),
#              'picture': Counter({'M': 3}),
#              'association': Counter({'M': 5, 'F': 7}),
#              'america': Counter({'M': 7}),
#              'films': Counter({'M': 1}),
#              'being': Counter({'M': 211, 'F': 24}),
#              'shown': Counter({'M': 7, 'F': 3}),
#              'authorities': Counter({'M': 20, 'F': 2}),
#              'widely': Counter({'M': 4}),
#              'multiple': Counter({'M': 23, 'F': 2}),
#              'two': Counter({'M': 420, 'F': 59}),
#              'stand': Counter({'M': 13, 'F': 3}),
#              'eleventh': Counter({'M': 34, 'F': 1}),
#              'north': Counter({'M': 20, 'F': 3}),
#              'carolina': Counter({'M': 15}),
#              'episodes': Counter({'M': 2}),
#              'reported': Counter({'M': 4, 'F': 2}),
#              'points': Counter({'M': 96, 'F': 22}),
#              'three': Counter({'M': 163, 'F': 38}),
#              'years': Counter({'M': 179, 'F': 20}),
#              'after': Counter({'M': 181, 'F': 21}),
#              'atascadero': Counter({'M': 1}),
#              'former': Counter({'M': 26}),
#              'emerging': Counter({'M': 5}),
#              'year': Counter({'M': 74, 'F': 6}),
#              'band': Counter({'M': 2}),
#              'lighter': Counter({'M': 1}),
#              'substantively': Counter({'M': 9, 'F': 6}),
#              'rule': Counter({'M': 695, 'F': 96}),
#              "'ve": Counter({'M': 251, 'F': 15}),
#              'since': Counter({'M': 63, 'F': 14}),
#              'founding': Counter({'M': 15}),
#              'everyone': Counter({'M': 35, 'F': 10}),
#              'agrees': Counter({'M': 42, 'F': 1}),
#              'obligation': Counter({'M': 68}),
#              'urging': Counter({'M': 5}),
#              'needs': Counter({'M': 56, 'F': 12}),
#              'reexamine': Counter({'M': 1}),
#              'sort': Counter({'M': 146, 'F': 68}),
#              'congruence': Counter({'M': 1}),
#              'proportionality': Counter({'M': 2}),
#              'rightfully': Counter({'M': 1, 'F': 2}),
#              'concerned': Counter({'M': 43, 'F': 2}),
#              'redefining': Counter({'M': 1}),
#              'substantive': Counter({'M': 61, 'F': 17}),
#              'intruding': Counter({'M': 2}),
#              'conduct': Counter({'M': 128, 'F': 12}),
#              'basically': Counter({'M': 52, 'F': 10}),
#              'changing': Counter({'M': 11, 'F': 1}),
#              'rules': Counter({'M': 87, 'F': 5}),
#              'constitute': Counter({'M': 9}),
#              'something': Counter({'M': 257, 'F': 42}),
#              'cardinal': Counter({'M': 1}),
#              'sin': Counter({'M': 2}),
#              'precisely': Counter({'M': 38, 'F': 4}),
#              'infringer': Counter({'M': 6, 'F': 1}),
#              'insist': Counter({'M': 3}),
#              'empirical': Counter({'M': 6}),
#              'scepticism': Counter({'M': 1}),
#              'especially': Counter({'M': 38, 'F': 2}),
#              'given': Counter({'M': 128, 'F': 8}),
#              'newly': Counter({'M': 6}),
#              'words': Counter({'M': 143, 'F': 31}),
#              'found': Counter({'M': 83, 'F': 22}),
#              'tip': Counter({'M': 5}),
#              'iceberg': Counter({'M': 4}),
#              'small': Counter({'M': 40, 'F': 7}),
#              'businesses': Counter({'M': 7, 'F': 1}),
#              'individual': Counter({'M': 97, 'F': 5}),
#              'incentives': Counter({'M': 8}),
#              'reporting': Counter({'M': 4, 'F': 1}),
#              'instances': Counter({'M': 25}),
#              'deprivation': Counter({'M': 7, 'F': 1}),
#              'course': Counter({'M': 223, 'F': 20}),
#              'complaint': Counter({'M': 114, 'F': 5}),
#              'dismiss': Counter({'M': 27, 'F': 1}),
#              'entitled': Counter({'M': 63, 'F': 7}),
#              'inferences': Counter({'M': 5}),
#              'drawn': Counter({'M': 14}),
#              'favor': Counter({'M': 35, 'F': 3}),
#              'allegations': Counter({'M': 41, 'F': 4}),
#              'looks': Counter({'M': 16, 'F': 8}),
#              'settlement': Counter({'M': 28, 'F': 3}),
#              'agreement': Counter({'M': 114, 'F': 5}),
#              'needed': Counter({'M': 30, 'F': 1}),
#              'watermarks': Counter({'M': 3}),
#              'timestamps': Counter({'M': 1}),
#              'images': Counter({'M': 16}),
#              'might': Counter({'M': 222, 'F': 39}),
#              'using': Counter({'M': 74, 'F': 9}),
#              'caught': Counter({'M': 5, 'F': 2}),
#              'red': Counter({'M': 16, 'F': 1}),
#              'handed': Counter({'M': 6, 'F': 1}),
#              'returned': Counter({'M': 11}),
#              'kept': Counter({'M': 7, 'F': 2}),
#              'up': Counter({'M': 262, 'F': 54}),
#              'filing': Counter({'M': 37}),
#              'lawsuit': Counter({'M': 32, 'F': 8}),
#              'too': Counter({'M': 64, 'F': 12}),
#              'blackbeard': Counter({'M': 5}),
#              'then': Counter({'M': 623, 'F': 94}),
#              'passed': Counter({'M': 42, 'F': 3}),
#              'sure': Counter({'M': 149, 'F': 38}),
#              'off': Counter({'M': 66, 'F': 19}),
#              'hook': Counter({'M': 4, 'F': 2}),
#              'liability': Counter({'M': 69, 'F': 8}),
#              'defense': Counter({'M': 53, 'F': 34}),
#              'parallel': Counter({'M': 14}),
#              'suit': Counter({'M': 60, 'F': 4}),
#              'evade': Counter({'M': 7}),
#              'look': Counter({'M': 416, 'F': 45}),
#              "'d": Counter({'M': 171, 'F': 22}),
#              'paragraphs': Counter({'M': 12}),
#              'paragraph': Counter({'M': 42}),
#              'explicit': Counter({'M': 22, 'F': 1}),
#              'intentional': Counter({'M': 15, 'F': 2}),
#              'uncompensated': Counter({'M': 1}),
#              'infringements': Counter({'M': 2, 'F': 1}),
#              'unconstitutional': Counter({'M': 52, 'F': 4}),
#              'violating': Counter({'M': 11, 'F': 5}),
#              'sorry': Counter({'M': 79, 'F': 9}),
#              'rationale': Counter({'M': 26}),
#              'u.s': Counter({'M': 149, 'F': 5}),
#              'georgia': Counter({'M': 37}),
#              'tennessee': Counter({'M': 4}),
#              'lane': Counter({'M': 7}),
#              'least': Counter({'M': 139, 'F': 26}),
#              'clients': Counter({'M': 50, 'F': 4}),
#              'proceed': Counter({'M': 27, 'F': 1}),
#              'show': Counter({'M': 50, 'F': 19}),
#              'dealing': Counter({'M': 49, 'F': 4}),
#              'body': Counter({'M': 32, 'F': 1}),
#              'innocent': Counter({'M': 12, 'F': 12}),
#              'independently': Counter({'M': 5, 'F': 1}),
#              'arrive': Counter({'M': 3}),
#              'invention': Counter({'M': 2, 'F': 1}),
#              'awareness': Counter({'M': 3, 'F': 1}),
#              'still': Counter({'M': 181, 'F': 22}),
#              'circumscribed': Counter({'M': 1}),
#              'requires': Counter({'M': 103, 'F': 23}),
#              'absent': Counter({'M': 27, 'F': 4}),
#              'oftentimes': Counter({'M': 3, 'F': 1}),
#              'bad': Counter({'M': 33, 'F': 8}),
#              'faith': Counter({'M': 58, 'F': 9}),
#              'encompassed': Counter({'M': 3}),
#              'referring': Counter({'M': 23, 'F': 3}),
#              'dozens': Counter({'M': 3}),
#              'received': Counter({'M': 15}),
#              'bigger': Counter({'M': 3, 'F': 1}),
#              'increasing': Counter({'M': 2}),
#              'per': Counter({'M': 12, 'F': 8}),
#              'decades': Counter({'M': 33, 'F': 5}),
#              'reality': Counter({'M': 14, 'F': 1}),
#              'saw': Counter({'M': 13, 'F': 3}),
#              'growing': Counter({'M': 1}),
#              'quickly': Counter({'M': 19}),
#              ';': Counter({'M': 100, 'F': 18}),
#              'remedies': Counter({'M': 43, 'F': 1}),
#              'place': Counter({'M': 108, 'F': 11}),
#              'order': Counter({'M': 209, 'F': 17}),
#              'stop': Counter({'M': 73, 'F': 3}),
#              'deter': Counter({'M': 6, 'F': 1}),
#              'amici': Counter({'M': 14, 'F': 2}),
#              'side': Counter({'M': 142, 'F': 20}),
#              'whole': Counter({'M': 81, 'F': 32}),
#              'chorus': Counter({'M': 2}),
#              'industry': Counter({'M': 10, 'F': 3}),
#              'associations': Counter({'M': 1, 'F': 1}),
#              'chamber': Counter({'M': 2}),
#              'alliance': Counter({'M': 1}),
#              'grown': Counter({'M': 2, 'F': 1}),
#              'wanted': Counter({'M': 120, 'F': 9}),
#              'ward': Counter({'M': 1}),
#              'perhaps': Counter({'M': 55, 'F': 3}),
#              'skeptical': Counter({'M': 6}),
#              'good': Counter({'M': 147, 'F': 24}),
#              'sound': Counter({'M': 10, 'F': 1}),
#              'paranoia': Counter({'M': 1}),
#              'pretextual': Counter({'M': 1, 'F': 1}),
#              'heartened': Counter({'M': 1}),
#              'feared': Counter({'M': 1}),
#              'come': Counter({'M': 131, 'F': 30}),
#              'pass': Counter({'M': 19}),
#              'over': Counter({'M': 226, 'F': 13}),
#              'sided': Counter({'M': 1}),
#              'confirms': Counter({'M': 4, 'F': 2}),
#              'soundness': Counter({'M': 1}),
#              'breyer': Counter({'M': 100, 'F': 9}),
#              'lot': Counter({'M': 76, 'F': 17}),
#              'mean': Counter({'M': 345, 'F': 58}),
#              'influenced': Counter({'M': 2}),
#              'licensing': Counter({'M': 5, 'F': 1}),
#              'entities': Counter({'M': 70, 'F': 1}),
#              'dow': Counter({'M': 1}),
#              'jones': Counter({'M': 35, 'F': 4}),
#              'committed': Counter({'M': 42, 'F': 5}),
#              'tens': Counter({'M': 5}),
#              'thousands': Counter({'M': 21, 'F': 3}),
#              'times': Counter({'M': 48, 'F': 14}),
#              'business': Counter({'M': 26, 'F': 12}),
#              'extent': Counter({'M': 63, 'F': 10}),
#              'maybe': Counter({'M': 91, 'F': 21}),
#              'afraid': Counter({'M': 2}),
#              'end': Counter({'M': 102, 'F': 14}),
#              'day': Counter({'M': 90, 'F': 7}),
#              'answer': Counter({'M': 233, 'F': 19}),
#              'unresolved': Counter({'M': 1, 'F': 3}),
#              'know': Counter({'M': 584, 'F': 153}),
#              'never': Counter({'M': 158, 'F': 38}),
#              'looked': Counter({'M': 60, 'F': 4}),
#              'predictive': Counter({'M': 3}),
#              'judgment': Counter({'M': 213, 'F': 25}),
#              'reasoned': Counter({'M': 9, 'F': 3}),
#              'logical': Counter({'M': 4, 'F': 2}),
#              'evidence': Counter({'M': 88, 'F': 48}),
#              'real': Counter({'M': 56, 'F': 9}),
#              'phenomenon': Counter({'M': 4}),
#              'sources': Counter({'M': 17, 'F': 4}),
#              'quite': Counter({'M': 68, 'F': 9}),
#              'concerning': Counter({'M': 10}),
#              'principles': Counter({'M': 104, 'F': 17}),
#              'among': Counter({'M': 23, 'F': 7}),
#              'others': Counter({'M': 37, 'F': 8}),
#              'decided': Counter({'M': 82, 'F': 9}),
#              'corroborated': Counter({'M': 1}),
#              'grounding': Counter({'M': 2}),
#              'evident': Counter({'M': 2}),
#              'happened': Counter({'M': 84, 'F': 9}),
#              'subsequent': Counter({'M': 19, 'F': 10}),
#              'go': Counter({'M': 205, 'F': 44}),
#              'perspective': Counter({'M': 12}),
#              'wrong': Counter({'M': 112, 'F': 36}),
#              'worse': Counter({'M': 12, 'F': 2}),
#              'taken': Counter({'M': 42, 'F': 6}),
#              'green': Counter({'M': 4}),
#              'light': Counter({'M': 21, 'F': 7}),
#              'continue': Counter({'M': 32, 'F': 5}),
#              'sufficiently': Counter({'M': 11, 'F': 1}),
#              'facts': Counter({'M': 142, 'F': 15}),
#              'specific': Counter({'M': 162, 'F': 21}),
#              'set': Counter({'M': 86, 'F': 10}),
#              'saying': Counter({'M': 228, 'F': 38}),
#              'violate': Counter({'M': 20, 'F': 4}),
#              'therefore': Counter({'M': 74, 'F': 6}),
#              'separate': Counter({'M': 86, 'F': 11}),
#              'applied': Counter({'M': 111, 'F': 13}),
#              'challenge': Counter({'M': 83, 'F': 9}),
#              'enacted': Counter({'M': 69, 'F': 4}),
#              'relied': Counter({'M': 21, 'F': 5}),
#              'us': Counter({'M': 123, 'F': 14}),
#              'wants': Counter({'M': 50, 'F': 16}),
#              'argue': Counter({'M': 43, 'F': 14}),
#              'application': Counter({'M': 106, 'F': 5}),
#              'burden': Counter({'M': 112, 'F': 20}),
#              'support': Counter({'M': 37, 'F': 2}),
#              'arguments': Counter({'M': 75, 'F': 15}),
#              'instance': Counter({'M': 68, 'F': 7}),
#              'simply': Counter({'M': 187, 'F': 27}),
#              'envisioned': Counter({'M': 2}),
#              'cite': Counter({'M': 54, 'F': 11}),
#              'trying': Counter({'M': 109, 'F': 17}),
#              'unconstitutionally': Counter({'M': 3, 'F': 1}),
#              'decides': Counter({'M': 19, 'F': 2}),
#              'often': Counter({'M': 55, 'F': 5}),
#              'comes': Counter({'M': 72, 'F': 9}),
#              'facial': Counter({'M': 7, 'F': 1}),
#              'challenges': Counter({'M': 12, 'F': 2}),
#              'facially': Counter({'M': 7}),
#              'appropriate': Counter({'M': 69, 'F': 12}),
#              'briefly': Counter({'M': 10, 'F': 5}),
#              'house': Counter({'M': 84, 'F': 10}),
#              'committee': Counter({'M': 43}),
#              'emphasized': Counter({'M': 12}),
#              'important': Counter({'M': 215, 'F': 34}),
#              'damages': Counter({'M': 138, 'F': 30}),
#              'specifically': Counter({'M': 97, 'F': 16}),
#              'statutory': Counter({'M': 160, 'F': 12}),
#              'attorneys': Counter({'M': 39, 'F': 4}),
#              'fees': Counter({'M': 71, 'F': 3}),
#              'loss': Counter({'M': 20}),
#              'protection': Counter({'M': 48, 'F': 14}),
#              'statute': Counter({'M': 639, 'F': 22}),
#              'preempts': Counter({'M': 3}),
#              'equivalent': Counter({'M': 12, 'F': 2}),
#              'laws': Counter({'M': 111, 'F': 11}),
#              'recourse': Counter({'M': 5}),
#              'complaining': Counter({'M': 4, 'F': 3}),
#              'outside': Counter({'M': 63, 'F': 11}),
#              'thank': Counter({'M': 167, 'F': 30}),
#              'feature': Counter({'M': 17, 'F': 3}),
#              'structure': Counter({'M': 43, 'F': 3}),
#              'repeatedly': Counter({'M': 32, 'F': 3}),
#              'reaffirmed': Counter({'M': 5}),
#              'lawsuits': Counter({'M': 9, 'F': 4}),
#              'seeking': Counter({'M': 67, 'F': 1}),
#              'inherent': Counter({'M': 10, 'F': 2}),
#              'remains': Counter({'M': 12, 'F': 5}),
#              'preserves': Counter({'M': 2, 'F': 4}),
#              'unless': Counter({'M': 48, 'F': 8}),
#              'compelling': Counter({'M': 17, 'F': 1}),
#              'surrendered': Counter({'M': 1}),
#              'ratified': Counter({'M': 9}),
#              'provision': Counter({'M': 199, 'F': 16}),
#              'friend': Counter({'M': 92, 'F': 7}),
#              'failed': Counter({'M': 14, 'F': 1}),
#              'identify': Counter({'M': 41, 'F': 7}),
#              'historical': Counter({'M': 69, 'F': 1}),
#              'remotely': Counter({'M': 1, 'F': 1}),
#              'contemplated': Counter({'M': 11}),
#              'allow': Counter({'M': 79, 'F': 10}),
#              'until': Counter({'M': 52, 'F': 9}),
#              '1970s': Counter({'M': 1}),
#              'nearly': Counter({'M': 13, 'F': 3}),
#              'centuries': Counter({'M': 14, 'F': 3}),
#              'awarded': Counter({'M': 12, 'F': 3}),
#              'now': Counter({'M': 358, 'F': 65}),
#              'allen': Counter({'M': 15}),
#              'seeks': Counter({'M': 10, 'F': 4}),
#              'portray': Counter({'M': 1}),
#              'settled': Counter({'M': 29, 'F': 7}),
#              'affairs': Counter({'M': 15, 'F': 1}),
#              'somehow': Counter({'M': 26, 'F': 3}),
#              'anomalous': Counter({'M': 3}),
#              'nothing': Counter({'M': 132, 'F': 13}),
#              'further': Counter({'M': 77, 'F': 10}),
#              'general': Counter({'M': 190, 'F': 5}),
#              'making': Counter({'M': 113, 'F': 7}),
#              'powers': Counter({'M': 76, 'F': 3}),
#              'subject': Counter({'M': 130, 'F': 7}),
#              'limits': Counter({'M': 48, 'F': 5}),
#              'elsewhere': Counter({'M': 9}),
#              'commandeer': Counter({'M': 1}),
#              'legislatures': Counter({'M': 3}),
#              'force': Counter({'M': 40}),
#              'protective': Counter({'M': 5}),
#              'nor': Counter({'M': 23, 'F': 4}),
#              'separation': Counter({'M': 44}),
#              'vest': Counter({'M': 7}),
#              'judicial': Counter({'M': 116, 'F': 3}),
#              'claims': Counter({'M': 232, 'F': 46}),
#              'senate': Counter({'M': 20}),
#              'judiciary': Counter({'M': 4}),
#              'likewise': Counter({'M': 6, 'F': 1}),
#              'authority': Counter({'M': 247, 'F': 9}),
#              'expose': Counter({'M': 3}),
#              'treasuries': Counter({'M': 1}),
#              'exorbitant': Counter({'M': 4}),
#              'financial': Counter({'M': 50, 'F': 1}),
#              'reason': Counter({'M': 289, 'F': 41}),
#              'justified': Counter({'M': 8, 'F': 2}),
#              'rarely': Counter({'M': 5, 'F': 2}),
#              'rises': Counter({'M': 4}),
#              'alone': Counter({'M': 30, 'F': 2}),
#              'pose': Counter({'M': 7, 'F': 1}),
#              'threat': Counter({'M': 8}),
#              'allows': Counter({'M': 31, 'F': 6}),
#              'expansive': Counter({'M': 5}),
#              'vastly': Counter({'M': 9}),
#              'greater': Counter({'M': 23, 'F': 12}),
#              'anything': Counter({'M': 113, 'F': 12}),
#              'required': Counter({'M': 131, 'F': 16}),
#              'includes': Counter({'M': 29, 'F': 4}),
#              'cur><number': Counter({'M': 43, 'F': 12}),
#              'plaintiff': Counter({'M': 87, 'F': 19}),
#              'prove': Counter({'M': 21, 'F': 7}),
#              'she': Counter({'M': 160, 'F': 8}),
#              'suffered': Counter({'M': 5, 'F': 1}),
#              'actual': Counter({'M': 110, 'F': 7}),
#              'harm': Counter({'M': 63, 'F': 7}),
#              'creates': Counter({'M': 25, 'F': 3}),
#              'strict': Counter({'M': 31, 'F': 3}),
#              'regime': Counter({'M': 20, 'F': 1}),
#              'covers': Counter({'M': 16}),
#              'though': Counter({'M': 107, 'F': 18}),
#              'deliberate': Counter({'M': 6, 'F': 1}),
#              'deprivations': Counter({'M': 1}),
#              'concerns': Counter({'M': 49, 'F': 7}),
#              'far': Counter({'M': 59, 'F': 2}),
#              'theoretical': Counter({'M': 4, 'F': 2}),
#              'circuit': Counter({'M': 317, 'F': 46}),
#              'affirmed': Counter({'M': 16}),
#              'college': Counter({'M': 10}),
#              'student': Counter({'M': 2}),
#              'sharing': Counter({'M': 8}),
#              'online': Counter({'M': 4}),
#              'few': Counter({'M': 57, 'F': 8}),
#              'copyrighted': Counter({'M': 8}),
#              'songs': Counter({'M': 1}),
#              'sending': Counter({'M': 9}),
#              'him': Counter({'M': 58, 'F': 10}),
#              'concern': Counter({'M': 57, 'F': 6}),
#              'ordinarily': Counter({'M': 12}),
#              'constitutionally': Counter({'M': 18, 'F': 1}),
#              'excessive': Counter({'M': 9, 'F': 4}),
#              'issues': Counter({'M': 66, 'F': 16}),
#              'start': Counter({'M': 64, 'F': 5}),
#              'invade': Counter({'M': 2}),
#              'hypothetical': Counter({'M': 80, 'F': 4}),
#              'misunderstands': Counter({'M': 2}),
#              'role': Counter({'M': 36, 'F': 7}),
#              'system': Counter({'M': 85, 'F': 7}),
#              'alden': Counter({'M': 1}),
#              'relieved': Counter({'M': 1}),
#              'binding': Counter({'M': 12, 'F': 5}),
#              'comply': Counter({'M': 19, 'F': 4}),
#              'ordinary': Counter({'M': 82, 'F': 14}),
#              'violates': Counter({'M': 18, 'F': 2}),
#              'injunction': Counter({'M': 78, 'F': 12}),
#              'agree': Counter({'M': 166, 'F': 16}),
#              'consequence': Counter({'M': 30, 'F': 1}),
#              'hard': Counter({'M': 53, 'F': 14}),
#              'remedied': Counter({'M': 2}),
#              'understanding': Counter({'M': 80, 'F': 11}),
#              'founders': Counter({'M': 1}),
#              'sue': Counter({'M': 45, 'F': 12}),
#              'opposite': Counter({'M': 25, 'F': 5}),
#              'people': Counter({'M': 203, 'F': 47}),
#              'entire': Counter({'M': 57, 'F': 5}),
#              'lewis': Counter({'M': 4}),
#              'ago': Counter({'M': 40, 'F': 5}),
#              'governments': Counter({'M': 9}),
#              'own': Counter({'M': 137, 'F': 10}),
#              'choices': Counter({'M': 5}),
#              'spend': Counter({'M': 11, 'F': 1}),
#              'scarce': Counter({'M': 2}),
#              'resources': Counter({'M': 41}),
#              'beauty': Counter({'M': 3}),
#              'combined': Counter({'M': 5}),
#              'extreme': Counter({'M': 7, 'F': 1}),
#              'hypotheticals': Counter({'M': 5, 'F': 4}),
#              'outlined': Counter({'M': 7, 'F': 1}),
#              'whenever': Counter({'M': 3}),
#              'reasonably': Counter({'M': 18}),
#              'allege': Counter({'M': 33}),
#              'adequate': Counter({'M': 18, 'F': 1}),
#              'bring': Counter({'M': 63, 'F': 12}),
#              'direct': Counter({'M': 42, 'F': 3}),
#              'claim': Counter({'M': 284, 'F': 42}),
#              'dispute': Counter({'M': 69, 'F': 2}),
#              'relieves': Counter({'M': 3}),
#              'many': Counter({'M': 144, 'F': 17}),
#              'discuss': Counter({'M': 9}),
#              'litigating': Counter({'M': 6}),
#              'four': Counter({'M': 45, 'F': 13}),
#              'his': Counter({'M': 206, 'F': 34}),
#              'reply': Counter({'M': 47, 'F': 8}),
#              'brief': Counter({'M': 268, 'F': 38}),
#              'wo': Counter({'M': 35, 'F': 6}),
#              'see': Counter({'M': 117, 'F': 28}),
#              'petition': Counter({'M': 83, 'F': 3}),
#              'briefs': Counter({'M': 41, 'F': 6}),
#              'below': Counter({'M': 82, 'F': 10}),
#              'transcripts': Counter({'M': 2}),
#              'lower': Counter({'M': 91, 'F': 14}),
#              'courts': Counter({'M': 374, 'F': 55}),
#              'naturally': Counter({'M': 5}),
#              'add': Counter({'M': 26, 'F': 4}),
#              'additional': Counter({'M': 52, 'F': 11}),
#              'element': Counter({'M': 44, 'F': 1}),
#              'complete': Counter({'M': 25}),
#              'features': Counter({'M': 6}),
#              'need': Counter({'M': 205, 'F': 43}),
#              'alternative': Counter({'M': 36, 'F': 2}),
#              'available': Counter({'M': 81, 'F': 8}),
#              'explicitly': Counter({'M': 15, 'F': 2}),
#              'bargained': Counter({'M': 2}),
#              'says': Counter({'M': 370, 'F': 56}),
#              'non': Counter({'M': 137, 'F': 6}),
#              'commercial': Counter({'M': 22, 'F': 4}),
#              'purposes': Counter({'M': 96, 'F': 10}),
#              'highlights': Counter({'M': 5}),
#              'scope': Counter({'M': 40, 'F': 7}),
#              'contractual': Counter({'M': 6, 'F': 2}),
#              'license': Counter({'M': 46, 'F': 13}),
#              'pending': Counter({'M': 19, 'F': 1}),
#              'breach': Counter({'M': 41}),
#              'contract': Counter({'M': 159, 'F': 13}),
#              'partner': Counter({'M': 2, 'F': 2}),
#              'intersal': Counter({'M': 4}),
#              'debating': Counter({'M': 2, 'F': 1}),
#              'exceeded': Counter({'M': 2}),
#              'example': Counter({'M': 229, 'F': 38}),
#              'putting': Counter({'M': 29, 'F': 5}),
#              'asserted': Counter({'M': 15}),
#              'affirmatively': Counter({'M': 11, 'F': 2}),
#              'waived': Counter({'M': 12, 'F': 6}),
#              'strange': Counter({'M': 9}),
#              'ca': Counter({'M': 210, 'F': 47}),
#              'possibly': Counter({'M': 19, 'F': 1}),
#              'relevance': Counter({'M': 5}),
#              'alleged': Counter({'M': 35, 'F': 3}),
#              'exposes': Counter({'M': 4}),
#              'second': Counter({'M': 298, 'F': 47}),
#              'types': Counter({'M': 30, 'F': 14}),
#              'related': Counter({'M': 44, 'F': 2}),
#              'declaratory': Counter({'M': 10}),
#              'declared': Counter({'M': 3, 'F': 1}),
#              'preempted': Counter({'M': 11, 'F': 1}),
#              'sought': Counter({'M': 30, 'F': 3}),
#              'cert': Counter({'M': 27, 'F': 6}),
#              'circumstance': Counter({'M': 64, 'F': 9}),
#              'district': Counter({'M': 243, 'F': 74}),
#              'fourth': Counter({'M': 47, 'F': 11}),
#              'pages': Counter({'M': 45, 'F': 8}),
#              'appendix': Counter({'M': 48, 'F': 15}),
#              ...})
